# %%
from tools import *
# Out:
# 2024-05-29 23:19:45,597 ib_async.client INFO Connecting to 127.0.0.1:4001 with clientId 10...
# 2024-05-29 23:19:45,599 ib_async.client INFO Connected
# 2024-05-29 23:19:45,602 ib_async.client INFO Logged on to server version 176
# 2024-05-29 23:19:45,604 ib_async.wrapper INFO Warning 2104, reqId -1: Market data farm connection is OK:usfuture
# 2024-05-29 23:19:45,605 ib_async.wrapper INFO Warning 2103, reqId -1: Market data farm connection is broken:usfarm
# 2024-05-29 23:19:45,607 ib_async.wrapper INFO Warning 2107, reqId -1: HMDS data farm connection is inactive but should be available upon demand.ushmds
# 2024-05-29 23:19:45,608 ib_async.client INFO API connection ready
# 2024-05-29 23:19:45,609 ib_async.wrapper INFO Warning 2158, reqId -1: Sec-def data farm connection is OK:secdefil
# 2024-05-29 23:19:45,613 ib_async.wrapper INFO position: Position(account='U2340948', contract=Stock(conId=4762, symbol='BA', exchange='NYSE', currency='USD', localSymbol='BA', tradingClass='BA'), position=254.0, avgCost=203.21112205)
# 2024-05-29 23:19:45,615 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=637079300, symbol='HYG', lastTradeDateOrContractMonth='20240621', strike=73.0, right='P', multiplier='100', currency='USD', localSymbol='HYG   240621P00073000', tradingClass='HYG'), position=50.0, avgCost=12.44685)
# 2024-05-29 23:19:45,616 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=682674010, symbol='AAPL', lastTradeDateOrContractMonth='20241018', strike=150.0, right='P', multiplier='100', currency='USD', localSymbol='AAPL  241018P00150000', tradingClass='AAPL'), position=4.0, avgCost=182.19685)
# 2024-05-29 23:19:45,617 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=657576926, symbol='QQQ', lastTradeDateOrContractMonth='20240930', strike=376.78, right='P', multiplier='100', currency='USD', localSymbol='QQQ   240930P00376780', tradingClass='QQQ'), position=1.0, avgCost=501.0369)
# 2024-05-29 23:19:45,619 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=669333316, symbol='NVDA', lastTradeDateOrContractMonth='20240719', strike=555.0, right='P', multiplier='100', currency='USD', localSymbol='NVDA  240719P00555000', tradingClass='NVDA'), position=2.0, avgCost=349.4231)
# 2024-05-29 23:19:45,620 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=613471094, symbol='GOOGL', lastTradeDateOrContractMonth='20240920', strike=120.0, right='P', multiplier='100', currency='USD', localSymbol='GOOGL 240920P00120000', tradingClass='GOOGL'), position=10.0, avgCost=51.44685)
# 2024-05-29 23:19:45,621 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=699061747, symbol='NVDA', lastTradeDateOrContractMonth='20240719', strike=855.0, right='P', multiplier='100', currency='USD', localSymbol='NVDA  240719P00855000', tradingClass='NVDA'), position=1.0, avgCost=593.0469)
# 2024-05-29 23:19:45,622 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=699536227, symbol='PINS', lastTradeDateOrContractMonth='20240607', strike=33.0, right='P', multiplier='100', currency='USD', localSymbol='PINS  240607P00033000', tradingClass='PINS'), position=40.0, avgCost=13.44685)
# 2024-05-29 23:19:45,623 ib_async.wrapper INFO position: Position(account='U10394496', contract=Future(conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', currency='USD', localSymbol='NQM4', tradingClass='NQ'), position=-2.0, avgCost=375798.0)
# 2024-05-29 23:19:45,624 ib_async.wrapper INFO position: Position(account='U2340948', contract=Stock(conId=47486780, symbol='EDV', exchange='ARCA', currency='USD', localSymbol='EDV', tradingClass='EDV'), position=650.0, avgCost=77.7080769)
# 2024-05-29 23:19:45,626 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=642744523, symbol='NVDA', lastTradeDateOrContractMonth='20240920', strike=510.0, right='P', multiplier='100', currency='USD', localSymbol='NVDA  240920P00510000', tradingClass='NVDA'), position=1.0, avgCost=501.0369)
# 2024-05-29 23:19:45,658 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=699532596, symbol='QQQ', lastTradeDateOrContractMonth='20240607', strike=400.0, right='P', multiplier='100', currency='USD', localSymbol='QQQ   240607P00400000', tradingClass='QQQ'), position=2.0, avgCost=207.69685)
# 2024-05-29 23:19:45,659 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=682677111, symbol='AMZN', lastTradeDateOrContractMonth='20241018', strike=130.0, right='P', multiplier='100', currency='USD', localSymbol='AMZN  241018P00130000', tradingClass='AMZN'), position=4.0, avgCost=115.68685)
# 2024-05-29 23:19:45,660 ib_async.wrapper INFO position: Position(account='U2340948', contract=Stock(conId=229726228, symbol='RSX', exchange='VALUE', currency='USD', localSymbol='RSX', tradingClass='RSX'), position=100.0, avgCost=6.889977)
# 2024-05-29 23:19:46,275 ib_async.wrapper INFO Warning 2104, reqId -1: Market data farm connection is OK:usfarm
# 2024-05-29 23:19:46,293 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565ad8.01.01', time=datetime.datetime(2024, 5, 29, 5, 31, 19, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18875.5, permId=1562025629, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18875.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,316 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565f44.01.01', time=datetime.datetime(2024, 5, 29, 7, 29, 51, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18871.75, permId=742998995, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18871.75, orderRef='VyOI0JRbZhfe', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,318 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565f49.01.01', time=datetime.datetime(2024, 5, 29, 7, 30, 13, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18869.25, permId=742998996, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18869.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,325 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565f64.01.01', time=datetime.datetime(2024, 5, 29, 7, 31, 36, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18859.5, permId=742998999, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18859.5, orderRef='Df6AmX4va1tp', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,329 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565f68.01.01', time=datetime.datetime(2024, 5, 29, 7, 31, 39, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18857.0, permId=742999000, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18857.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,331 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565f6b.01.01', time=datetime.datetime(2024, 5, 29, 7, 31, 45, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18855.25, permId=742999001, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18855.25, orderRef='TYA11TjzdsCX', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,334 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565f72.01.01', time=datetime.datetime(2024, 5, 29, 7, 32, 8, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18852.75, permId=742999002, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18852.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,339 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565fdf.01.01', time=datetime.datetime(2024, 5, 29, 7, 37, 30, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18855.5, permId=742999003, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18855.5, orderRef='Xlwwtl5sDXla', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,341 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565fe5.01.01', time=datetime.datetime(2024, 5, 29, 7, 38, 14, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18853.0, permId=742999004, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18853.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,344 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565fe7.01.01', time=datetime.datetime(2024, 5, 29, 7, 38, 29, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18853.0, permId=742999019, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18853.0, orderRef='txbJnSHRTdGh', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,346 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565fe9.01.01', time=datetime.datetime(2024, 5, 29, 7, 39, 24, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18850.5, permId=742999020, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18850.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,349 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565ff9.01.01', time=datetime.datetime(2024, 5, 29, 7, 40, 49, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18856.25, permId=742999021, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18856.25, orderRef='kPNzKK8Y56yW', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,354 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66565ffc.01.01', time=datetime.datetime(2024, 5, 29, 7, 42, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18853.75, permId=742999022, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18853.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,357 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566003.01.01', time=datetime.datetime(2024, 5, 29, 7, 43, 34, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18856.75, permId=742999023, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18856.75, orderRef='GPjge2ozBp2A', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,360 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566006.01.01', time=datetime.datetime(2024, 5, 29, 7, 44, 6, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18854.25, permId=742999024, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18854.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,364 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656600e.01.01', time=datetime.datetime(2024, 5, 29, 7, 44, 28, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18857.0, permId=742999025, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18857.0, orderRef='zxJofufDTMbm', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,366 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566010.01.01', time=datetime.datetime(2024, 5, 29, 7, 44, 34, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18854.5, permId=742999026, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18854.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,369 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566018.01.01', time=datetime.datetime(2024, 5, 29, 7, 45, 51, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18860.25, permId=742999027, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18860.25, orderRef='fPwOP2dX6B52', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,372 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566033.01.01', time=datetime.datetime(2024, 5, 29, 7, 48, 13, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18857.75, permId=742999028, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18857.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,376 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566036.01.01', time=datetime.datetime(2024, 5, 29, 7, 48, 53, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18860.5, permId=742999029, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18860.5, orderRef='rkVh0H0Syxjz', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,379 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566040.01.01', time=datetime.datetime(2024, 5, 29, 7, 51, 8, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18857.5, permId=742999030, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18857.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,384 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566097.01.01', time=datetime.datetime(2024, 5, 29, 7, 59, 37, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=2.0, price=18851.75, permId=742999035, clientId=0, orderId=0, liquidation=0, cumQty=2.0, avgPrice=18851.75, orderRef='smCj71PNufzq', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,386 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665660a5.01.01', time=datetime.datetime(2024, 5, 29, 8, 0, 9, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18853.75, permId=742999036, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18853.75, orderRef='Pw5cBVr3J5wN', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,390 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665660a6.01.01', time=datetime.datetime(2024, 5, 29, 8, 0, 20, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18856.25, permId=742999037, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18856.25, orderRef='shoWaiwIHqNJ', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,392 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665660ac.01.01', time=datetime.datetime(2024, 5, 29, 8, 0, 34, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18858.75, permId=742999038, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18858.75, orderRef='kE1T5tAszoK5', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,396 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566103.01.01', time=datetime.datetime(2024, 5, 29, 8, 7, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18854.75, permId=742999039, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18854.75, orderRef='0RhWpVGpsfkf', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,400 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656610d.01.01', time=datetime.datetime(2024, 5, 29, 8, 7, 19, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18852.25, permId=742999040, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18852.25, orderRef='4q92Db8H4gyO', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,403 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566112.01.01', time=datetime.datetime(2024, 5, 29, 8, 7, 55, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18849.75, permId=742999041, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18849.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,406 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566148.01.01', time=datetime.datetime(2024, 5, 29, 8, 9, 5, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18846.25, permId=742999042, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18846.25, orderRef='XGuXXeS6z0xy', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,407 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656614d.01.01', time=datetime.datetime(2024, 5, 29, 8, 9, 8, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18843.75, permId=742999043, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18843.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,410 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566152.01.01', time=datetime.datetime(2024, 5, 29, 8, 9, 17, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18843.0, permId=742999044, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18843.0, orderRef='9GzvsxBjx6yO', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,413 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566154.01.01', time=datetime.datetime(2024, 5, 29, 8, 9, 23, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18840.5, permId=742999045, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18840.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,417 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656615c.01.01', time=datetime.datetime(2024, 5, 29, 8, 9, 36, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18840.0, permId=742999046, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18840.0, orderRef='mLXOkTbKZo8Y', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,418 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656616b.01.01', time=datetime.datetime(2024, 5, 29, 8, 10, 34, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18837.5, permId=742999047, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18837.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,420 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656634f.01.01', time=datetime.datetime(2024, 5, 29, 8, 37, 7, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18821.5, permId=742999050, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18821.5, orderRef='CdSs5PrGMMLM', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,423 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66566370.01.01', time=datetime.datetime(2024, 5, 29, 8, 40, 43, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18819.0, permId=742999051, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18819.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,426 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665674af.01.01', time=datetime.datetime(2024, 5, 29, 13, 9, 28, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18769.5, permId=742999082, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18769.5, orderRef='BxddvSgw3ZS2', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,428 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665686e8.01.01', time=datetime.datetime(2024, 5, 29, 13, 49, 13, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18799.0, permId=743000104, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18799.0, orderRef='bbu6jlw2K5Zu', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,432 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665686ff.01.01', time=datetime.datetime(2024, 5, 29, 13, 49, 20, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18801.75, permId=743000105, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18801.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,433 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656873c.01.01', time=datetime.datetime(2024, 5, 29, 13, 49, 50, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18806.25, permId=743000106, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18806.25, orderRef='5m4uJ7x0cpws', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,434 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656873d.01.01', time=datetime.datetime(2024, 5, 29, 13, 49, 51, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18808.75, permId=743000107, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18808.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,437 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656875f.01.01', time=datetime.datetime(2024, 5, 29, 13, 50, 4, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18808.0, permId=743000108, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18808.0, orderRef='W63Yht4laAx1', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,439 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568762.01.01', time=datetime.datetime(2024, 5, 29, 13, 50, 6, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18810.5, permId=743000109, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18810.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,441 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656883d.01.01', time=datetime.datetime(2024, 5, 29, 13, 50, 18, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18827.75, permId=743000110, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18827.75, orderRef='ciuHXsRF7c2J', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,442 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656887a.01.01', time=datetime.datetime(2024, 5, 29, 13, 50, 27, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18830.25, permId=743000111, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18830.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,443 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568965.01.01', time=datetime.datetime(2024, 5, 29, 13, 51, 7, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18836.0, permId=743000112, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18836.0, orderRef='bjAYG3gneCn5', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,444 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665689f0.01.01', time=datetime.datetime(2024, 5, 29, 13, 51, 47, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18838.5, permId=743000113, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18838.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,446 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568a2b.01.01', time=datetime.datetime(2024, 5, 29, 13, 52, 6, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18832.25, permId=743000156, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18832.25, orderRef='SRq1RZV1Whib', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,447 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568a45.01.01', time=datetime.datetime(2024, 5, 29, 13, 52, 12, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18834.75, permId=743000157, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18834.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,449 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568a4d.01.01', time=datetime.datetime(2024, 5, 29, 13, 52, 18, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18832.75, permId=743000158, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18832.75, orderRef='aYKiDSTuN7RZ', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,450 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568a61.01.01', time=datetime.datetime(2024, 5, 29, 13, 52, 30, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18835.25, permId=743000159, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18835.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,451 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568a7a.01.01', time=datetime.datetime(2024, 5, 29, 13, 52, 38, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18838.0, permId=743000160, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18838.0, orderRef='8iTV7Bx0y5dK', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,452 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568ad8.01.01', time=datetime.datetime(2024, 5, 29, 13, 53, 21, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18841.25, permId=743000161, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18841.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,453 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568c15.01.01', time=datetime.datetime(2024, 5, 29, 13, 55, 3, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18842.75, permId=743000169, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18842.75, orderRef='wH2XDe8C6LAk', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,455 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568cc6.01.01', time=datetime.datetime(2024, 5, 29, 13, 56, 30, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18840.0, permId=743000170, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18840.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,456 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568cfa.01.01', time=datetime.datetime(2024, 5, 29, 13, 56, 46, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18839.75, permId=743000171, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18839.75, orderRef='in6lboVTJp0c', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,458 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568d50.01.01', time=datetime.datetime(2024, 5, 29, 13, 57, 46, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18837.0, permId=743000172, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18837.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,459 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568d7e.01.01', time=datetime.datetime(2024, 5, 29, 13, 57, 55, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18836.0, permId=743000174, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18836.0, orderRef='yUfcadCSwKWh', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,461 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568dc8.01.01', time=datetime.datetime(2024, 5, 29, 13, 58, 33, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18833.25, permId=743000175, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18833.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,462 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568df5.01.01', time=datetime.datetime(2024, 5, 29, 13, 58, 47, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18834.5, permId=743000179, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18834.5, orderRef='SselacaEUT5K', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,464 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568e00.01.01', time=datetime.datetime(2024, 5, 29, 13, 58, 59, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18832.0, permId=743000180, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18832.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,465 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568e25.01.01', time=datetime.datetime(2024, 5, 29, 13, 59, 8, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18832.75, permId=743000181, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18832.75, orderRef='qXd0awBbTTCf', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,466 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568e5c.01.01', time=datetime.datetime(2024, 5, 29, 13, 59, 41, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18830.25, permId=743000182, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18830.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,468 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568e6a.01.01', time=datetime.datetime(2024, 5, 29, 13, 59, 50, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18831.25, permId=743000183, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18831.25, orderRef='V1QtBWc2YsJG', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,469 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568ec9.01.01', time=datetime.datetime(2024, 5, 29, 14, 0, 29, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18828.5, permId=743000184, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18828.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,470 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568ee1.01.01', time=datetime.datetime(2024, 5, 29, 14, 0, 43, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18832.25, permId=743000186, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18832.25, orderRef='cv3kNM5xqxSj', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,471 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568efc.01.01', time=datetime.datetime(2024, 5, 29, 14, 0, 57, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18829.0, permId=743000187, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18829.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,473 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568f0f.01.01', time=datetime.datetime(2024, 5, 29, 14, 1, 17, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18832.25, permId=743000188, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18832.25, orderRef='j51fqzIcSTAS', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,474 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568f65.01.01', time=datetime.datetime(2024, 5, 29, 14, 1, 59, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18829.75, permId=743000189, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18829.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,478 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568f93.01.01', time=datetime.datetime(2024, 5, 29, 14, 2, 7, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18828.75, permId=743000234, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18828.75, orderRef='GLOachDSuqhT', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,479 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568fa8.01.01', time=datetime.datetime(2024, 5, 29, 14, 2, 15, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18826.0, permId=743000235, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18826.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,481 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568fc0.01.01', time=datetime.datetime(2024, 5, 29, 14, 2, 26, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18829.5, permId=743000236, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18829.5, orderRef='A3OGxVU9NSfw', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,482 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568fc9.01.01', time=datetime.datetime(2024, 5, 29, 14, 2, 29, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18827.0, permId=743000237, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18827.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,484 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66568fe9.01.01', time=datetime.datetime(2024, 5, 29, 14, 2, 35, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18823.5, permId=743000238, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18823.5, orderRef='cIv45xygJIuD', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,486 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656901d.01.01', time=datetime.datetime(2024, 5, 29, 14, 3, 1, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18821.0, permId=743000239, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18821.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,487 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66569067.01.01', time=datetime.datetime(2024, 5, 29, 14, 3, 19, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18822.5, permId=743000240, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18822.5, orderRef='q1ErHVdtFoPh', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,489 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66569089.01.01', time=datetime.datetime(2024, 5, 29, 14, 3, 29, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18819.5, permId=743000241, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18819.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,491 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656909e.01.01', time=datetime.datetime(2024, 5, 29, 14, 3, 42, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18824.0, permId=743000242, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18824.0, orderRef='flgveD3foQbT', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,493 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665690dd.01.01', time=datetime.datetime(2024, 5, 29, 14, 4, 7, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18821.5, permId=743000243, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18821.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,494 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665690fd.01.01', time=datetime.datetime(2024, 5, 29, 14, 4, 23, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18826.0, permId=743000382, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18826.0, orderRef='fmwRou7MdXzQ', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,496 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665691e5.01.01', time=datetime.datetime(2024, 5, 29, 14, 6, 3, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18823.5, permId=743000383, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18823.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,498 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656921a.01.01', time=datetime.datetime(2024, 5, 29, 14, 6, 17, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18822.75, permId=743000457, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18822.75, orderRef='Gl1veBMK20wE', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,499 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66569226.01.01', time=datetime.datetime(2024, 5, 29, 14, 6, 21, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18820.25, permId=743000458, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18820.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,500 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656926d.01.01', time=datetime.datetime(2024, 5, 29, 14, 6, 28, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18815.75, permId=743000459, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18815.75, orderRef='s6AYabnnRNZf', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False)
# 2024-05-29 23:19:46,501 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665693f2.01.01', time=datetime.datetime(2024, 5, 29, 14, 8, 24, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18812.5, permId=743000460, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18812.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,503 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656946e.01.01', time=datetime.datetime(2024, 5, 29, 14, 9, 15, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18815.75, permId=743000468, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18815.75, orderRef='4K0sbCcfvO60', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,504 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66569470.01.01', time=datetime.datetime(2024, 5, 29, 14, 9, 17, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18813.75, permId=743000469, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18813.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,506 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66569797.01.01', time=datetime.datetime(2024, 5, 29, 14, 17, 25, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18843.0, permId=743000479, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18843.0, orderRef='egIgcwq8OemG', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,507 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.6656979d.01.01', time=datetime.datetime(2024, 5, 29, 14, 17, 33, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18840.5, permId=743000480, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18840.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,508 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665697ad.01.01', time=datetime.datetime(2024, 5, 29, 14, 17, 46, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18841.75, permId=743000483, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18841.75, orderRef='78JDWRQlsGvw', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,509 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66569806.01.01', time=datetime.datetime(2024, 5, 29, 14, 18, 55, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18839.25, permId=743000485, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18839.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,510 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.665698aa.01.01', time=datetime.datetime(2024, 5, 29, 14, 20, 25, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18839.75, permId=743000491, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18839.75, orderRef='aqMFyPhstRp0', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,511 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66569957.01.01', time=datetime.datetime(2024, 5, 29, 14, 21, 17, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18837.25, permId=743000492, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18837.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-29 23:19:46,512 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.66569a71.01.01', time=datetime.datetime(2024, 5, 29, 14, 22, 34, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18825.5, permId=743000493, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=18825.5, orderRef='9MNjEcvZZEkQ', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# ...
# 2024-05-29 23:44:13,746 ib_async.wrapper INFO orderStatus: Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18675.5, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0)], advancedError='')
# 2024-05-29 23:44:21,625 ib_async.wrapper INFO orderStatus: Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18676.5, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0)], advancedError='')
# 2024-05-29 23:44:49,110 ib_async.wrapper INFO orderStatus: Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 57716, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 109563, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0)], advancedError='')
# 2024-05-29 23:44:51,505 ib_async.wrapper INFO orderStatus: Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 57716, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 109563, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 470966, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 504337, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0)], advancedError='')
# 2024-05-29 23:44:53,913 ib_async.wrapper INFO orderStatus: Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 57716, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 109563, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 470966, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 504337, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 53, 821166, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 53, 912483, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0)], advancedError='')
# 2024-05-29 23:44:56,233 ib_async.wrapper INFO orderStatus: Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18676.75, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 57716, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 109563, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 470966, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 504337, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 53, 821166, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 53, 912483, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 56, 180888, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 56, 232732, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0)], advancedError='')
# 2024-05-29 23:44:58,590 ib_async.wrapper INFO orderStatus: Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 57716, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 109563, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 470966, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 504337, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 53, 821166, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 53, 912483, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 56, 180888, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 56, 232732, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 58, 551013, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 58, 589845, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0)], advancedError='')
# 2024-05-29 23:45:01,222 ib_async.client ERROR Peer closed connection.

# %%
# Out:
# [2024-05-29 23:44:46.994260] {'strategy': 'SELL TO OPEN SCALP', 'contract': 'NQM2024', 'tick_increment': 0.25, 'open_qty': 1, 'open_type': 'LIMIT', 'open_action': 'SELL', 'open_ref': 'ask', 'open_ticks': 10, 'close_qty': 1, 'close_type': 'LIMIT', 'close_action': 'BUY', 'close_ref': 'open_fill', 'close_ticks': -10, 'pause_seconds': 90} / 1622695088 / None
# [2024-05-29 23:44:47.364788] OPEN TRADE:: Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18676.5, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0)], advancedError='')
# Error sending request: Request Entity Too Large
# [2024-05-29 23:44:47.665571] CLOSE TRADE:: None
# 2024-05-29 23:44:49,058 ib_async.ib INFO placeOrder: Modify order Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 57716, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0)], advancedError='')
# --------------------------------------------------
# ------- SELL TO OPEN SCALP / 10--10 / 90 seconds -------
# --------------------------------------------------
# symbol	permId		status		action	filled	remaining	lmtPrice
# NQ	1622695088	Submitted	SELL	0.0	1.0		18676.5
# --------------------------------------------------
# Waiting to get filled on order #1622695088 (Submitted)
# OPEN Trade submitted, but not filled. Modifying order limit price: 18676.5
# Modifying order: LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496')
# [2024-05-29 23:44:50.061949] MODIFIED ORDER PLACED:: LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496')
#
# --------------------------------------------------
#      3.0    18674.0 | 18674.75   5.0
#      5.0   18673.75 | 18675.0    9.0
#      3.0    18673.5 | 18675.25   5.0
#      4.0   18673.25 | 18675.5    7.0
#      3.0    18673.0 | 18675.75   4.0
# --------------------------------------------------
# Positions:
# BA	254.0 @ 203.21112205
# EDV	650.0 @ 77.7080769
# RSX	100.0 @ 6.889977
# HYG	50.0 @ 0.1244685
# AAPL	4.0 @ 1.8219685
# QQQ	1.0 @ 5.010369
# NVDA	2.0 @ 3.4942309999999996
# GOOGL	10.0 @ 0.5144685
# NVDA	1.0 @ 5.930469
# PINS	40.0 @ 0.1344685
# NQ	-2.0 @ 18789.9
# NVDA	1.0 @ 5.010369
# QQQ	2.0 @ 2.0769685
# AMZN	4.0 @ 1.1568685
# --------------------------------------------------
# Open Orders: 6
#    orderId      permId action  totalQuantity orderType  lmtPrice  tif
# 2        0  1607911182   SELL            1.0       LMT  18848.25  GTC
# 3        0  1950795534   SELL            1.0       LMT  18796.75  GTC
# 4        0  1950795535    BUY            1.0       LMT  18794.25  GTC
# 0        0  1950795558   SELL            1.0       LMT  18784.00  GTC
# 1        0  1950795559    BUY            1.0       LMT  18781.50  GTC
# 5        9  1622695088   SELL            1.0       LMT  18677.00
# --------------------------------------------------
# Account: U10394496
# Cushion 0.598474
# LookAheadExcessLiquidity 82651.47
# NetLiquidation 115811.24
# TotalCashValue 113781.67
# Account: U2340948
# Cushion 1
# LookAheadExcessLiquidity 343.82
# NetLiquidation 89559.75
# TotalCashValue 343.82
# --------------------------------------------------
# 2024-05-29 23:44:51,471 ib_async.ib INFO placeOrder: Modify order Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 57716, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 109563, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 470966, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0)], advancedError='')
# --------------------------------------------------
# ------- SELL TO OPEN SCALP / 10--10 / 90 seconds -------
# --------------------------------------------------
# symbol	permId		status		action	filled	remaining	lmtPrice
# NQ	1622695088	Submitted	SELL	0.0	1.0		18677.0
# --------------------------------------------------
# Waiting to get filled on order #1622695088 (Submitted)
# OPEN Trade submitted, but not filled. Modifying order limit price: 18677.0
# Modifying order: LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496')
# [2024-05-29 23:44:52.474261] MODIFIED ORDER PLACED:: LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496')
#
# --------------------------------------------------
#      5.0   18673.75 | 18674.5    3.0
#      4.0    18673.5 | 18674.75   3.0
#      4.0   18673.25 | 18675.0    9.0
#      3.0    18673.0 | 18675.25   6.0
#      5.0   18672.75 | 18675.5    7.0
# --------------------------------------------------
# Positions:
# BA	254.0 @ 203.21112205
# EDV	650.0 @ 77.7080769
# RSX	100.0 @ 6.889977
# HYG	50.0 @ 0.1244685
# AAPL	4.0 @ 1.8219685
# QQQ	1.0 @ 5.010369
# NVDA	2.0 @ 3.4942309999999996
# GOOGL	10.0 @ 0.5144685
# NVDA	1.0 @ 5.930469
# PINS	40.0 @ 0.1344685
# NQ	-2.0 @ 18789.9
# NVDA	1.0 @ 5.010369
# QQQ	2.0 @ 2.0769685
# AMZN	4.0 @ 1.1568685
# --------------------------------------------------
# Open Orders: 6
#    orderId      permId action  totalQuantity orderType  lmtPrice  tif
# 2        0  1607911182   SELL            1.0       LMT  18848.25  GTC
# 3        0  1950795534   SELL            1.0       LMT  18796.75  GTC
# 4        0  1950795535    BUY            1.0       LMT  18794.25  GTC
# 0        0  1950795558   SELL            1.0       LMT  18784.00  GTC
# 1        0  1950795559    BUY            1.0       LMT  18781.50  GTC
# 5        9  1622695088   SELL            1.0       LMT  18677.00
# --------------------------------------------------
# Account: U10394496
# Cushion 0.598474
# LookAheadExcessLiquidity 82651.47
# NetLiquidation 115811.24
# TotalCashValue 113781.67
# Account: U2340948
# Cushion 1
# LookAheadExcessLiquidity 343.82
# NetLiquidation 89559.75
# TotalCashValue 343.82
# --------------------------------------------------
# 2024-05-29 23:44:53,821 ib_async.ib INFO placeOrder: Modify order Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 57716, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 109563, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 470966, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 504337, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 53, 821166, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0)], advancedError='')
# --------------------------------------------------
# ------- SELL TO OPEN SCALP / 10--10 / 90 seconds -------
# --------------------------------------------------
# symbol	permId		status		action	filled	remaining	lmtPrice
# NQ	1622695088	Submitted	SELL	0.0	1.0		18677.0
# --------------------------------------------------
# Waiting to get filled on order #1622695088 (Submitted)
# OPEN Trade submitted, but not filled. Modifying order limit price: 18677.0
# Modifying order: LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496')
# [2024-05-29 23:44:54.826386] MODIFIED ORDER PLACED:: LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496')
#
# --------------------------------------------------
#      5.0   18673.75 | 18674.5    2.0
#      5.0    18673.5 | 18674.75   3.0
#      4.0   18673.25 | 18675.0    9.0
#      4.0    18673.0 | 18675.25   5.0
#      5.0   18672.75 | 18675.5    7.0
# --------------------------------------------------
# Positions:
# BA	254.0 @ 203.21112205
# EDV	650.0 @ 77.7080769
# RSX	100.0 @ 6.889977
# HYG	50.0 @ 0.1244685
# AAPL	4.0 @ 1.8219685
# QQQ	1.0 @ 5.010369
# NVDA	2.0 @ 3.4942309999999996
# GOOGL	10.0 @ 0.5144685
# NVDA	1.0 @ 5.930469
# PINS	40.0 @ 0.1344685
# NQ	-2.0 @ 18789.9
# NVDA	1.0 @ 5.010369
# QQQ	2.0 @ 2.0769685
# AMZN	4.0 @ 1.1568685
# --------------------------------------------------
# Open Orders: 6
#    orderId      permId action  totalQuantity orderType  lmtPrice  tif
# 2        0  1607911182   SELL            1.0       LMT  18848.25  GTC
# 3        0  1950795534   SELL            1.0       LMT  18796.75  GTC
# 4        0  1950795535    BUY            1.0       LMT  18794.25  GTC
# 0        0  1950795558   SELL            1.0       LMT  18784.00  GTC
# 1        0  1950795559    BUY            1.0       LMT  18781.50  GTC
# 5        9  1622695088   SELL            1.0       LMT  18677.00
# --------------------------------------------------
# Account: U10394496
# Cushion 0.598474
# LookAheadExcessLiquidity 82651.47
# NetLiquidation 115811.24
# TotalCashValue 113781.67
# Account: U2340948
# Cushion 1
# LookAheadExcessLiquidity 343.82
# NetLiquidation 89559.75
# TotalCashValue 343.82
# --------------------------------------------------
# 2024-05-29 23:44:56,181 ib_async.ib INFO placeOrder: Modify order Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18676.75, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 57716, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 109563, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 470966, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 504337, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 53, 821166, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 53, 912483, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 56, 180888, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0)], advancedError='')
# --------------------------------------------------
# ------- SELL TO OPEN SCALP / 10--10 / 90 seconds -------
# --------------------------------------------------
# symbol	permId		status		action	filled	remaining	lmtPrice
# NQ	1622695088	Submitted	SELL	0.0	1.0		18677.0
# --------------------------------------------------
# Waiting to get filled on order #1622695088 (Submitted)
# OPEN Trade submitted, but not filled. Modifying order limit price: 18677.0
# Modifying order: LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18676.75, auxPrice=0.0, account='U10394496')
# [2024-05-29 23:44:57.183986] MODIFIED ORDER PLACED:: LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18676.75, auxPrice=0.0, account='U10394496')
#
# --------------------------------------------------
#      4.0   18673.75 | 18674.5    2.0
#      5.0    18673.5 | 18674.75   4.0
#      4.0   18673.25 | 18675.0    9.0
#      3.0    18673.0 | 18675.25   5.0
#      5.0   18672.75 | 18675.5    7.0
# --------------------------------------------------
# Positions:
# BA	254.0 @ 203.21112205
# EDV	650.0 @ 77.7080769
# RSX	100.0 @ 6.889977
# HYG	50.0 @ 0.1244685
# AAPL	4.0 @ 1.8219685
# QQQ	1.0 @ 5.010369
# NVDA	2.0 @ 3.4942309999999996
# GOOGL	10.0 @ 0.5144685
# NVDA	1.0 @ 5.930469
# PINS	40.0 @ 0.1344685
# NQ	-2.0 @ 18789.9
# NVDA	1.0 @ 5.010369
# QQQ	2.0 @ 2.0769685
# AMZN	4.0 @ 1.1568685
# --------------------------------------------------
# Open Orders: 6
#    orderId      permId action  totalQuantity orderType  lmtPrice  tif
# 2        0  1607911182   SELL            1.0       LMT  18848.25  GTC
# 3        0  1950795534   SELL            1.0       LMT  18796.75  GTC
# 4        0  1950795535    BUY            1.0       LMT  18794.25  GTC
# 0        0  1950795558   SELL            1.0       LMT  18784.00  GTC
# 1        0  1950795559    BUY            1.0       LMT  18781.50  GTC
# 5        9  1622695088   SELL            1.0       LMT  18676.75
# --------------------------------------------------
# Account: U10394496
# Cushion 0.598474
# LookAheadExcessLiquidity 82651.47
# NetLiquidation 115811.24
# TotalCashValue 113781.67
# Account: U2340948
# Cushion 1
# LookAheadExcessLiquidity 343.82
# NetLiquidation 89559.75
# TotalCashValue 343.82
# --------------------------------------------------
# 2024-05-29 23:44:58,551 ib_async.ib INFO placeOrder: Modify order Trade(contract=Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496'), orderStatus=OrderStatus(orderId=9, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1622695088, parentId=0, lastFillPrice=0.0, clientId=10, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 497789, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 42, 37, 962567, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 484252, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 13, 744331, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 553529, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 21, 623818, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 57716, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 49, 109563, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 470966, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 51, 504337, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 53, 821166, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 53, 912483, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 56, 180888, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 56, 232732, tzinfo=datetime.timezone.utc), status='Submitted', message='Modified', errorCode=0), TradeLogEntry(time=datetime.datetime(2024, 5, 30, 4, 44, 58, 551013, tzinfo=datetime.timezone.utc), status='Submitted', message='Modify', errorCode=0)], advancedError='')
# --------------------------------------------------
# ------- SELL TO OPEN SCALP / 10--10 / 90 seconds -------
# --------------------------------------------------
# symbol	permId		status		action	filled	remaining	lmtPrice
# NQ	1622695088	Submitted	SELL	0.0	1.0		18676.75
# --------------------------------------------------
# Waiting to get filled on order #1622695088 (Submitted)
# OPEN Trade submitted, but not filled. Modifying order limit price: 18676.75
# Modifying order: LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496')
# [2024-05-29 23:44:59.554108] MODIFIED ORDER PLACED:: LimitOrder(orderId=9, clientId=10, permId=1622695088, action='SELL', totalQuantity=1.0, lmtPrice=18677.0, auxPrice=0.0, account='U10394496')
#
# --------------------------------------------------
#      2.0   18673.75 | 18674.25   1.0
#      5.0    18673.5 | 18674.5    3.0
#      4.0   18673.25 | 18674.75   5.0
#      3.0    18673.0 | 18675.0    9.0
#      5.0   18672.75 | 18675.25   5.0
# --------------------------------------------------
# Positions:
# BA	254.0 @ 203.21112205
# EDV	650.0 @ 77.7080769
# RSX	100.0 @ 6.889977
# HYG	50.0 @ 0.1244685
# AAPL	4.0 @ 1.8219685
# QQQ	1.0 @ 5.010369
# NVDA	2.0 @ 3.4942309999999996
# GOOGL	10.0 @ 0.5144685
# NVDA	1.0 @ 5.930469
# PINS	40.0 @ 0.1344685
# NQ	-2.0 @ 18789.9
# NVDA	1.0 @ 5.010369
# QQQ	2.0 @ 2.0769685
# AMZN	4.0 @ 1.1568685
# --------------------------------------------------
# Open Orders: 6
#    orderId      permId action  totalQuantity orderType  lmtPrice  tif
# 2        0  1607911182   SELL            1.0       LMT  18848.25  GTC
# 3        0  1950795534   SELL            1.0       LMT  18796.75  GTC
# 4        0  1950795535    BUY            1.0       LMT  18794.25  GTC
# 0        0  1950795558   SELL            1.0       LMT  18784.00  GTC
# 1        0  1950795559    BUY            1.0       LMT  18781.50  GTC
# 5        9  1622695088   SELL            1.0       LMT  18677.00
# --------------------------------------------------
# Account: U10394496
# Cushion 0.598474
# LookAheadExcessLiquidity 82651.47
# NetLiquidation 115811.24
# TotalCashValue 113781.67
# Account: U2340948
# Cushion 1
# LookAheadExcessLiquidity 343.82
# NetLiquidation 89559.75
# TotalCashValue 343.82
# --------------------------------------------------
# --------------------------------------------------
# ------- SELL TO OPEN SCALP / 10--10 / 90 seconds -------
# --------------------------------------------------
# symbol	permId		status		action	filled	remaining	lmtPrice
# NQ	1622695088	Submitted	SELL	0.0	1.0		18677.0
# --------------------------------------------------
# Waiting to get filled on order #1622695088 (Submitted)
# OPEN Trade submitted, but not filled. Modifying order limit price: 18677.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 299
#     265 SELL_SCALP = {
#     266     "strategy": "SELL TO OPEN SCALP",
#     267     "contract": "NQM2024",
#    (...)
#     279     "pause_seconds": 90,
#     280 }
#     282 BUY_SCALP = {
#     283     "strategy": "BUY TO OPEN SCALP",
#     284     "contract": "NQM2024",
#    (...)
#     296     "pause_seconds": 70,
#     297 }
# --> 299 run_ss_2(strategy_details=SELL_SCALP, open_permid=1622695088, close_permid = None)
#
# Cell In[7], line 132, in run_ss_2(strategy_details, open_permid, close_permid)
#     130     price_ref = ticker.domBids[0].price
#     131 elif strategy_details["open_ref"] == "ask":
# --> 132     price_ref = ticker.domAsks[0].price
#     133 elif strategy_details["open_ref"] == "mid":
#     134     price_ref = (ticker.domAsks[0].price + ticker.domBids[0].price) / 2
#
# IndexError: list index out of range

# %%
open_permid = ib.executions()[-1].permId
print(next((trade for trade in ib.trades() if trade.order.permId == open_permid), None))

# %%
ib.openTrades()[-1].order.permId

# %%
open_trade = next((trade for trade in ib.trades() if trade.order.permId == open_permid), None)
print(open_trade.fills[0].execution.avgPrice)

# %%
print(last_trade.order.lmtPrice)

# %%
ib.openTrades()

# %%
ib.openOrders()

# %%
close_trade = [o for o in ib.openOrders() if o.permId == 974395978][0]
close_trade.order

# %%
trades = parse_ibrecords(ib.trades())
submittedTrades = [o for o in trades if o["status"] == "Submitted"]

print_ibrecords_table(
    submittedTrades,
    ["orderId", "permId", "status", "orderType", "action", "lmtPrice", "remaining"],
)

# %%
# openTrades = parse_ibrecords(ib.openTrades())
accountSummary = ib.accountSummary()
accountValues = ib.accountValues()

# openTrades = parse_ibrecords(ib.openTrades())
# # util.df([d for d in openTrades])

# print_ibrecords_table(openTrades)

# openOrders = parse_ibrecords(ib.openOrders())
# util.df([d for d in openOrders])

# trades = parse_ibrecords(ib.trades())
# util.df([d for d in trades])

# orders = parse_ibrecords(ib.orders())
# util.df([d for d in orders])


openOrders = parse_ibrecords(ib.openOrders())
openOrders

# %%
ord = ib.orders()

[print(o) for o in ord if o.permId == 1394515162]

# %%
util.df(ib.orders())

# %%
util.df(ib.openOrders())

# %%
from datetime import datetime

input_string = "20240930 16:00:00 Central Standard Time"
date_format = "%Y%m%d %H:%M:%S %Z"

try:
    datetime_object = datetime.strptime(input_string, date_format)
    print(datetime_object)
except ValueError:
    print(f"Incorrect date format.")

# %%
util.df([t for t in ib.reqAllOpenOrders()])

# %%
clear_output()
o = ib.orders()[0]
o = util.dataclassNonDefaults(o)
o.pop("softDollarTier", None)
o.pop("shareholder", None)
o.pop("autoCancelDate", None)
o.pop("auxPrice", None)

data, count = supabase.table("orders").upsert(o).execute()

util.tree(o)

# %%
o["autoCancelDate"]

# %%
od = util.dataclassAsDict(o)
print(od)

# %%
clear_output()
o = ib.orders()[0]
od = util.dataclassAsDict(o)

data, count = supabase.table("orders").upsert(od).execute()

# %%
clear_output()
util.dataclassRepr(ib.trades()[0])

# util.dataclassAsDict(executions[0])

# %%
# Get Account details
details = ib.accountSummary()
details_df = util.df(details)

# Tag Values
# tags = details_df['tag'].values.tolist()
# print(tags)

# Set tag values as index
details_df = details_df.set_index("tag")
net_liquidation_value = details_df.loc["NetLiquidation", "value"]
details_df

# %%
util.tree(ib.trades()[0])

# %%
util.tree(ib.openTrades()[0])

# %%
trades = ib.reqAllOpenOrders()

trades.sort(key=lambda trade: trade.order.lmtPrice)

for trade in trades:
    orderstatus = trade.orderStatus
    order = trade.order

    if trade.contract.symbol != "NQ":
        continue

    print(
        f"{trade.contract.symbol}\t{order.permId}\t{orderstatus.status}\t{order.action}\t{orderstatus.filled}\t{orderstatus.remaining}\t\t{order.lmtPrice}\t"
    )

# %%
trades_df = util.df(ib.trades())
trades_df

# %%
DEBUG = True
LIVE = True

def get_cencelled_orders():
    return [trade for trade in ib.trades() if trade.fills != []]

def get_trade_by_permid(permid):
    return next((trade for trade in ib.trades() if trade.order.permId == permid), None)

def get_last_executed_trade():
    return get_trade_by_permid(permid = (ib.executions()[-1].permId))

last_trade = get_last_executed_trade()


def run_ss_2(strategy_details, open_permid = None, close_permid = None):
    if open_permid is not None or close_permid is not None:
        # check trades first
        executed = ib.trades()
        open_trade = next((trade for trade in executed if trade.order.permId == open_permid), None)
        close_trade = next((trade for trade in executed if trade.order.permId == close_permid), None)
    else:
        open_trade = None
        close_trade = None

    open_order_ts = None

    if LIVE:
        push_notifications(
            f"{strategy_details} / {open_permid} / {close_permid}"
        )

        push_notifications(f"OPEN TRADE:: {open_trade}")
        push_notifications(f"CLOSE TRADE:: {close_trade}")
    else:
        print(f"OPEN TRADE:: {open_trade}")
        print(f"CLOSE TRADE:: {close_trade}")

    pause = False

    while ib.sleep(1):
        print_line()
        print(f"------- {strategy_details['strategy']} / {strategy_details['open_ticks']}-{strategy_details['close_ticks']} / {strategy_details['pause_seconds']} seconds -------")
        print_line()        

        # first order of the strategy
        if open_trade is None and close_trade is None:
            action = strategy_details["open_action"]
            qty = strategy_details["open_qty"]

            if ticker is None or len(ticker.domBids) == 0 or len(ticker.domAsks) == 0:
                print(f"************ Issue getting orderbook tickers *************** ")
                alert(True)
                ib.waitOnUpdate()
                continue

            if strategy_details["open_ref"] == "bid":
                price_ref = ticker.domBids[0].price
            elif strategy_details["open_ref"] == "ask":
                price_ref = ticker.domAsks[0].price
            elif strategy_details["open_ref"] == "mid":
                price_ref = (ticker.domAsks[0].price + ticker.domBids[0].price) / 2
            else:
                raise Exception("Not implemented")

            lmtPrice = (
                price_ref
                + strategy_details["open_ticks"] * strategy_details["tick_increment"]
            )

            if strategy_details["open_type"] == "LIMIT":
                open_order = LimitOrder(
                    action=action,
                    totalQuantity=qty,
                    lmtPrice=lmtPrice,
                    account="U10394496",
                )
            else:
                raise Exception("Not implemented")

            print(f"Placing order for open_trade {open_order} ")

            if LIVE:
                open_trade = ib.placeOrder(NQM4, open_order)
                ib.sleep(1)

                trade = open_trade
                push_notifications(
                    f"OPEN ORDER PLACED :: #{trade.order.permId} {trade.orderStatus.status} {trade.contract.symbol} {trade.order.action} {trade.orderStatus.filled}/{trade.orderStatus.remaining} @ {trade.order.lmtPrice}"
                )
            else:
                print(f"OPEN ORDER PLACED :: {open_order}")     
                print("Not live (0)")
            
            open_order_ts = datetime.datetime.now()
        
        print_order(open_trade)
        print_line()

        if open_trade is not None:

            if (
                open_trade.orderStatus.status == "Inactive"
                or open_trade.orderStatus.status == "Cancelled"
            ) and close_trade is None:
                
                if LIVE:
                    push_notifications(f"OPEN TRADE CANCELLED:: {open_trade.order}")
                else:
                    print(f"OPEN TRADE CANCELLED:: {open_trade.order}")
                    print('Not live (1)')

                print("Order cancelled/inactive. Resetting open_trade to None")
                open_trade = None
        
            elif open_trade.orderStatus.status == "Submitted" and close_trade is None:
                print(
                    f"Waiting to get filled on order #{open_trade.order.permId} ({open_trade.orderStatus.status})"
                )

                if (
                    open_order_ts is None
                    or datetime.datetime.now() - open_order_ts
                    > datetime.timedelta(seconds=strategy_details["pause_seconds"])
                ):
                    print(f"OPEN Trade submitted, but not filled. Modifying order limit price: {open_trade.order.lmtPrice}")

                    # find the price of opening the trade
                    if strategy_details["open_ref"] == "bid":
                        price_ref = ticker.domBids[0].price
                    elif strategy_details["open_ref"] == "ask":
                        price_ref = ticker.domAsks[0].price
                    elif strategy_details["open_ref"] == "mid":
                        price_ref = (ticker.domAsks[0].price + ticker.domBids[0].price) / 2
                    else:
                        raise Exception("Not implemented")

                    lmtPrice = (
                        price_ref
                        + strategy_details["open_ticks"] * strategy_details["tick_increment"]
                    )

                    open_trade.order.lmtPrice = lmtPrice

                    print(f"Modifying order: {open_trade.order}")

                    if LIVE:
                        open_trade = ib.placeOrder(NQM4, open_trade.order)
                        ib.sleep(1)
                        push_notifications(f"MODIFIED ORDER PLACED:: {open_trade.order}")
                    else:
                        print(f"MODIFIED ORDER PLACED:: {open_trade.order}")
                        print("Not live (2)")

            elif open_trade.orderStatus.status == "Filled" and close_trade is None:
                print(f"Filled on open_trade {open_trade.orderStatus.status} {open_trade.orderStatus.avgFillPrice} {open_trade.orderStatus.status}")

                action = strategy_details["close_action"]
                qty = strategy_details["close_qty"]

                # find the price to close the trade
                if strategy_details["close_ref"] == "open_fill":
                    price_ref = open_trade.fills[0].execution.avgPrice
                elif strategy_details["close_ref"] == "bid":
                    price_ref = ticker.domBids[0].price
                elif strategy_details["close_ref"] == "ask":
                    price_ref = ticker.domAsks[0].price
                elif strategy_details["close_ref"] == "mid":
                    price_ref = (ticker.domAsks[0].price + ticker.domBids[0].price) / 2
                else:
                    raise Exception("Not implemented")

                lmtPrice = (
                    price_ref
                    + strategy_details["close_ticks"]
                    * strategy_details["tick_increment"]
                )

                if strategy_details["close_type"] == "LIMIT":
                    close_order = LimitOrder(
                        action=action,
                        totalQuantity=qty,
                        lmtPrice=lmtPrice,
                        account="U10394496",
                    )
                else:
                    raise Exception("Not implemented")

                print("Placing close_order {close_order}")

                if LIVE:
                    close_trade = ib.placeOrder(NQM4, close_order)
                    ib.sleep(1)
                    push_notifications(msg=f"OPEN ORDER FILLED:: {open_trade.order}")
                    push_notifications(msg=f"CLOSE ORDER PLACED:: {close_trade.order}")
                    alert(False)
                else:
                    print(f"[NOT LIVE] OPEN ORDER FILLED:: {open_trade.order}")
                    # print(f"CLOSE ORDER PLACED:: {close_trade.order}")
                    
        print_order(close_trade)
        print_line()
    
        if close_trade is not None:
            if close_trade.orderStatus.status == "Filled":
                print(f"Close trade filled @ {close_trade.orderStatus.avgFillPrice}")
                print_line()

                if LIVE:
                    push_notifications(f"CLOSE TRADE FILLED:: {close_trade.order}")
                    alert(True)
                else:
                    print(f"[NOT LIVE] CLOSE TRADE FILLED:: {close_trade.order}")
            
                open_trade = None
                close_trade = None
                pause = True
            elif (
                close_trade.orderStatus.status == "Inactive"
                or close_trade.orderStatus.status == "Cancelled"
            ) and close_trade is None:
                
                if LIVE:
                    push_notifications(f"CLOSE TRADE CANCELLED:: {close_trade.order}")
                else:
                    print(f"CLOSE TRADE CANCELLED:: {close_trade.order}")
                    print('Not live (11)')

                print("Order cancelled/inactive. Resetting close_trade to None")
                close_trade = None

        print_orderbook()
        print_line()

        print_positions()
        print_line()

        print_openOrders()
        print_line()

        # openOrders = parse_ibrecords(ib.openOrders())
        # print_ibrecords_table(
        #     openOrders,
        #     cols=[
        #         "localSymbol",
        #         "permId",
        #         "status",
        #         "orderType",
        #         "action",
        #         "lmtPrice",
        #         "remaining",
        #     ],
        # )

        print_account_summary()
        print_line()

        if pause:
            ib.sleep(strategy_details["pause_seconds"])
            pause = False

        print_clear()


SELL_SCALP = {
    "strategy": "SELL TO OPEN SCALP",
    "contract": "NQM2024",
    "tick_increment": 0.25,
    "open_qty": 1,
    "open_type": "LIMIT",
    "open_action": "SELL",
    "open_ref": "ask",
    "open_ticks": 10,
    "close_qty": 1,
    "close_type": "LIMIT",
    "close_action": "BUY",
    "close_ref": "open_fill",
    "close_ticks": -10,
    "pause_seconds": 90,
}

BUY_SCALP = {
    "strategy": "BUY TO OPEN SCALP",
    "contract": "NQM2024",
    "tick_increment": 0.25,
    "open_qty": 1,
    "open_type": "LIMIT",
    "open_action": "BUY",
    "open_ref": "ask",
    "open_ticks": -10,
    "close_qty": 1,
    "close_type": "LIMIT",
    "close_action": "SELL",
    "close_ref": "open_fill",
    "close_ticks": 10,
    "pause_seconds": 70,
}

run_ss_2(strategy_details=SELL_SCALP, open_permid=1622695088, close_permid = None)

# %%
# get all the trades where fills is not []
fills = trades_df[trades_df.fills.map(len) > 0]

fills_list = list(fills["order"])

# loop through fills and convert each member of this data type to a row in a df
#  Order(permId=253828901, action='BUY', orderType='LMT', lmtPrice=17580.0, auxPrice=0.0, tif='GTC', ocaType=3, displaySize=2147483647, rule80A='0', openClose='', volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='U10394496', clearingIntent='IB', cashQty=0.0, dontUseAutoPriceForHedge=True, autoCancelDate='20240930 16:00:00 Central Standard Time', filledQuantity=1.0, refFuturesConId=2147483647, shareholder='Not an insider or substantial shareholder')
