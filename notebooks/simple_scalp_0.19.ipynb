# %%
from IPython.core.display import HTML
from IPython.display import display, clear_output

display(HTML("<style>.output_subarea { overflow: auto; }</style>"))

import chime
import datetime
import random
import os
import pandas as pd
import socket

from supabase import create_client, Client
from ib_async import *

import urllib

if "ib" in globals() or "ib" in locals():
    ib.disconnect()

hostname = socket.gethostname()
util.logToFile(f"{datetime.datetime.now().strftime('%Y-%m-%d')}-{hostname}.log")
util.startLoop()

randint = lambda a=1, b=10: random.randint(a, b)
ib = IB()
ib.connect("127.0.0.1", 4001, clientId=randint(1, 10))

# setup listeners for ib
# NQM2024 contract
print("Setting contract to NQM2024 symbol / JUN 2024 / Contract(conId=620730920)")
contract = Contract(conId=620730920)
ib.qualifyContracts(contract)

ticker = ib.reqMktDepth(contract)
positions = ib.reqPositions()
summary = ib.reqAccountSummary()
openorders = ib.reqAllOpenOrders()
executions = ib.reqExecutions()


# connect to supabase server
url: str = "https://dbcizmxdlufqncxipqwt.supabase.co"
key: str = (
    "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImRiY2l6bXhkbHVmcW5jeGlwcXd0Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MDE4NDkxMTMsImV4cCI6MjAxNzQyNTExM30.ys98bhleekrfDJAbrMMqXGsVh1XMa3Vtl8O62s7D5as"
)
supabase: Client = create_client(url, key)

print("Sleeping 5 seconds to load data...")

ib.sleep(5)
# Out:
# True

# %%
def push_msg(msg="Hello world!"):
    try:
        body = f"[{datetime.datetime.now()}] {msg}"
        print(body)
        data = urllib.parse.urlencode({"text": body}).encode()
        req = urllib.request.Request(
            "https://api.chanify.net/v1/sender/CICswLUGEiJBQUZIR0pJQ0VVNkxUTlZCMk1DRElCWU1RSlNWMktCS0NFIgIIAQ.vj8gcfxM4jD9Zv0mBMSlFlY51EL_jC5dB8LWdWX1tAs",
            data=data,
        )
        response = urllib.request.urlopen(req)
        response.read()  # Read the response to ensure the request is complete
    except urllib.error.URLError as e:
        print(f"Error sending request: {e.reason}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")


push_msg("testing")


def import_trades(trades):
    for t in trades:
        print(t)
        d = {
            "contract_sectype": t.contract.secType,
            "contract_conid": int(t.contract.conId),
            "contract_symbol": t.contract.symbol,
            "contract_lasttradedateorcontractmonth": t.contract.lastTradeDateOrContractMonth,
            "contract_multiplier": int("1" or t.contract.multiplier),
            "contract_currency": t.contract.currency,
            "contract_localsymbol": t.contract.localSymbol,
            "contract_tradingclass": t.contract.tradingClass,
            "order_permid": int(t.order.permId),
            "order_action": t.order.action,
            "order_ordertype": t.order.orderType,
            "order_lmtprice": float(t.order.lmtPrice),
            "order_tif": t.order.tif,
            "order_ocatype": t.order.ocaType,
            "order_account": t.order.account,
            "order_autocanceldate": t.order.autoCancelDate,
            "order_filledquantity": float(t.order.filledQuantity),
            "order_reffuturesconid": int(t.order.refFuturesConId),
            "orderstatus": t.orderStatus.status,
        }

        data, count = supabase.table("trades").upsert(d).execute()

    print(f"Imported {len(trades)} trades")


print("OPEN ORDERS::")
# print([t for t in ib.openTrades() if t.order.action == "SELL"])
print([t for t in ib.openTrades()])
# Out:
# [2024-05-22 15:00:32.707729] testing
# OPEN ORDERS::
# [Trade(contract=Future(conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', right='?', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=Order(orderId=113, clientId=2, permId=390987485, action='BUY', totalQuantity=1.0, orderType='LMT', lmtPrice=18711.25, auxPrice=0.0, tif='GTC', ocaType=3, displaySize=2147483647, rule80A='0', openClose='', volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='U10394496', clearingIntent='IB', adjustedOrderType='None', cashQty=0.0, dontUseAutoPriceForHedge=True), orderStatus=OrderStatus(orderId=113, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=390987485, parentId=0, lastFillPrice=0.0, clientId=2, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 22, 20, 0, 21, 897894, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0)], advancedError=''), Trade(contract=Future(conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', right='?', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=Order(permId=2099801404, action='BUY', totalQuantity=1.0, orderType='LMT', lmtPrice=18040.5, auxPrice=0.0, tif='GTC', ocaGroup='2099801403', ocaType=3, displaySize=2147483647, rule80A='0', openClose='', volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='U10394496', clearingIntent='IB', adjustedOrderType='None', cashQty=0.0, dontUseAutoPriceForHedge=True), orderStatus=OrderStatus(orderId=0, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=2099801404, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 22, 20, 0, 21, 932142, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0)], advancedError=''), Trade(contract=Future(conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', right='?', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=Order(orderId=75, clientId=2, permId=390987450, action='SELL', totalQuantity=1.0, orderType='LMT', lmtPrice=18837.5, auxPrice=0.0, tif='GTC', ocaType=3, displaySize=2147483647, rule80A='0', openClose='', volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='U10394496', clearingIntent='IB', adjustedOrderType='None', cashQty=0.0, dontUseAutoPriceForHedge=True), orderStatus=OrderStatus(orderId=75, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=390987450, parentId=0, lastFillPrice=0.0, clientId=2, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 22, 20, 0, 21, 932142, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0)], advancedError=''), Trade(contract=Future(conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', right='?', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ'), order=Order(permId=1276830230, action='BUY', totalQuantity=1.0, orderType='LMT', lmtPrice=18642.5, auxPrice=0.0, tif='GTC', ocaGroup='1276830229', ocaType=3, displaySize=2147483647, rule80A='0', openClose='', volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='U10394496', clearingIntent='IB', adjustedOrderType='None', cashQty=0.0, dontUseAutoPriceForHedge=True), orderStatus=OrderStatus(orderId=0, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1276830230, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2024, 5, 22, 20, 0, 21, 932142, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0)], advancedError='')]

# %%
print("CLOSED TRADES::")
util.tree([t for t in ib.trades()])
# Out:
# CLOSED TRADES::
# [{'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1550602048,
#      'action': 'BUY',
#      'orderType': 'LMT',
#      'lmtPrice': 18686.75,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d8b86.01.01',
#        'time': '2024-05-22T18:42:17+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18686.75,
#        'permId': 1550602048,
#        'clientId': 6,
#        'orderId': 19,
#        'cumQty': 1.0,
#        'avgPrice': 18686.75,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d8b86.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': 376.944289}},
#      'time': '2024-05-22T18:42:17+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T18:42:17+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18686.75'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669661,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18799.25,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669660,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18799.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669663,
#      'action': 'BUY',
#      'orderType': 'LMT',
#      'lmtPrice': 18801.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d1eaf.01.01',
#        'time': '2024-05-22T07:58:21+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18801.5,
#        'permId': 1636669663,
#        'clientId': 6,
#        'orderId': 138,
#        'cumQty': 1.0,
#        'avgPrice': 18801.5,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d1eaf.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': 107.313477}},
#      'time': '2024-05-22T07:58:21+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T07:58:21+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18801.5'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669662,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18800.75,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669657,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18800.25,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669656,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18798.25,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669659,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18800.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669658,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18799.0,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669653,
#      'action': 'BUY',
#      'orderType': 'LMT',
#      'lmtPrice': 18797.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d1da2.01.01',
#        'time': '2024-05-22T07:27:52+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18797.5,
#        'permId': 1636669653,
#        'clientId': 6,
#        'orderId': 128,
#        'cumQty': 1.0,
#        'avgPrice': 18797.5,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d1da2.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': 234.417969}},
#      'time': '2024-05-22T07:27:52+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T07:27:52+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18797.5'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669652,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18798.75,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669655,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18797.75,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669654,
#      'action': 'SELL',
#      'orderType': 'LMT',
#      'lmtPrice': 18800.0,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d1e8b.01.01',
#        'time': '2024-05-22T07:43:02+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'SLD',
#        'shares': 1.0,
#        'price': 18800.0,
#        'permId': 1636669654,
#        'clientId': 6,
#        'orderId': 129,
#        'cumQty': 1.0,
#        'avgPrice': 18800.0,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d1e8b.01.01',
#        'commission': 2.0,
#        'currency': 'USD'}},
#      'time': '2024-05-22T07:43:02+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T07:43:02+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18800.0'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669677,
#      'action': 'BUY',
#      'orderType': 'LMT',
#      'lmtPrice': 18807.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d2c3d.01.01',
#        'time': '2024-05-22T13:24:19+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18807.5,
#        'permId': 1636669677,
#        'clientId': 6,
#        'orderId': 152,
#        'cumQty': 1.0,
#        'avgPrice': 18807.5,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d2c3d.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': -1.617993}},
#      'time': '2024-05-22T13:24:19+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T13:24:19+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18807.5'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669676,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18807.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669679,
#      'action': 'BUY',
#      'orderType': 'LMT',
#      'lmtPrice': 18815.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d2ea0.01.01',
#        'time': '2024-05-22T13:31:52+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18815.5,
#        'permId': 1636669679,
#        'clientId': 6,
#        'orderId': 154,
#        'cumQty': 1.0,
#        'avgPrice': 18815.5,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d2ea0.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': -149.713495}},
#      'time': '2024-05-22T13:31:52+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T13:31:52+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18815.5'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669678,
#      'action': 'SELL',
#      'orderType': 'LMT',
#      'lmtPrice': 18810.0,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d2d09.01.01',
#        'time': '2024-05-22T13:30:00+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'SLD',
#        'shares': 1.0,
#        'price': 18810.0,
#        'permId': 1636669678,
#        'clientId': 6,
#        'orderId': 153,
#        'cumQty': 1.0,
#        'avgPrice': 18810.0,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d2d09.01.01',
#        'commission': 2.0,
#        'currency': 'USD'}},
#      'time': '2024-05-22T13:30:00+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T13:30:00+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18810.0'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669673,
#      'action': 'BUY',
#      'orderType': 'LMT',
#      'lmtPrice': 18804.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d2a8c.01.01',
#        'time': '2024-05-22T13:05:40+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18804.5,
#        'permId': 1636669673,
#        'clientId': 6,
#        'orderId': 148,
#        'cumQty': 1.0,
#        'avgPrice': 18804.5,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d2a8c.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': 62.509342}},
#      'time': '2024-05-22T13:05:40+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T13:05:40+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18804.5'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669672,
#      'action': 'SELL',
#      'orderType': 'LMT',
#      'lmtPrice': 18811.25,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d2a34.01.01',
#        'time': '2024-05-22T13:04:07+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'SLD',
#        'shares': 1.0,
#        'price': 18811.25,
#        'permId': 1636669672,
#        'clientId': 6,
#        'orderId': 147,
#        'cumQty': 1.0,
#        'avgPrice': 18811.25,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d2a34.01.01',
#        'commission': 2.0,
#        'currency': 'USD'}},
#      'time': '2024-05-22T13:04:07+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T13:04:07+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18811.25'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669675,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18805.75,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669674,
#      'action': 'SELL',
#      'orderType': 'LMT',
#      'lmtPrice': 18807.0,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d2ba9.01.01',
#        'time': '2024-05-22T13:18:43+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'SLD',
#        'shares': 1.0,
#        'price': 18807.0,
#        'permId': 1636669674,
#        'clientId': 6,
#        'orderId': 149,
#        'cumQty': 1.0,
#        'avgPrice': 18807.0,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d2ba9.01.01',
#        'commission': 2.0,
#        'currency': 'USD'}},
#      'time': '2024-05-22T13:18:43+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T13:18:43+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18807.0'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669669,
#      'action': 'SELL',
#      'orderType': 'LMT',
#      'lmtPrice': 18807.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d24bf.01.01',
#        'time': '2024-05-22T11:06:47+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'SLD',
#        'shares': 1.0,
#        'price': 18807.5,
#        'permId': 1636669669,
#        'clientId': 6,
#        'orderId': 144,
#        'cumQty': 1.0,
#        'avgPrice': 18807.5,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d24bf.01.01',
#        'commission': 2.0,
#        'currency': 'USD'}},
#      'time': '2024-05-22T11:06:47+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T11:06:47+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18807.5'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669668,
#      'action': 'BUY',
#      'orderType': 'LMT',
#      'lmtPrice': 18805.0,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d1f61.01.01',
#        'time': '2024-05-22T08:17:05+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18805.0,
#        'permId': 1636669668,
#        'clientId': 6,
#        'orderId': 143,
#        'cumQty': 1.0,
#        'avgPrice': 18805.0,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d1f61.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': 24.238831}},
#      'time': '2024-05-22T08:17:05+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T08:17:05+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18805.0'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669671,
#      'action': 'BUY',
#      'orderType': 'LMT',
#      'lmtPrice': 18808.75,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d2516.01.01',
#        'time': '2024-05-22T11:09:58+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18808.75,
#        'permId': 1636669671,
#        'clientId': 6,
#        'orderId': 146,
#        'cumQty': 1.0,
#        'avgPrice': 18808.75,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d2516.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': -45.320877}},
#      'time': '2024-05-22T11:09:58+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T11:09:58+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18808.75'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669670,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18805.75,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669665,
#      'action': 'BUY',
#      'orderType': 'LMT',
#      'lmtPrice': 18804.25,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d1eff.01.01',
#        'time': '2024-05-22T08:05:08+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18804.25,
#        'permId': 1636669665,
#        'clientId': 6,
#        'orderId': 140,
#        'cumQty': 1.0,
#        'avgPrice': 18804.25,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d1eff.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': 36.985107}},
#      'time': '2024-05-22T08:05:08+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T08:05:08+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18804.25'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669664,
#      'action': 'SELL',
#      'orderType': 'LMT',
#      'lmtPrice': 18804.0,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d1ec6.01.01',
#        'time': '2024-05-22T08:02:24+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'SLD',
#        'shares': 1.0,
#        'price': 18804.0,
#        'permId': 1636669664,
#        'clientId': 6,
#        'orderId': 139,
#        'cumQty': 1.0,
#        'avgPrice': 18804.0,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d1ec6.01.01',
#        'commission': 2.0,
#        'currency': 'USD'}},
#      'time': '2024-05-22T08:02:24+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T08:02:24+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18804.0'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669667,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18804.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 0.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Cancelled'}}}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1636669666,
#      'action': 'SELL',
#      'orderType': 'LMT',
#      'lmtPrice': 18806.75,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 17:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d1f47.01.01',
#        'time': '2024-05-22T08:12:50+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'SLD',
#        'shares': 1.0,
#        'price': 18806.75,
#        'permId': 1636669666,
#        'clientId': 6,
#        'orderId': 141,
#        'cumQty': 1.0,
#        'avgPrice': 18806.75,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d1f47.01.01',
#        'commission': 2.0,
#        'currency': 'USD'}},
#      'time': '2024-05-22T08:12:50+00:00'}],
# ...
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d568c.01.01',
#        'time': '2024-05-22T15:22:00+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18834.5,
#        'permId': 390987443,
#        'clientId': 2,
#        'orderId': 68,
#        'cumQty': 1.0,
#        'avgPrice': 18834.5,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d568c.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': -94.433136}},
#      'time': '2024-05-22T15:22:00+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T15:22:00+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18834.5'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 390987442,
#      'action': 'SELL',
#      'orderType': 'LMT',
#      'lmtPrice': 18837.75,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d5645.01.01',
#        'time': '2024-05-22T15:20:11+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'SLD',
#        'shares': 1.0,
#        'price': 18837.75,
#        'permId': 390987442,
#        'clientId': 2,
#        'orderId': 67,
#        'cumQty': 1.0,
#        'avgPrice': 18837.75,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d5645.01.01',
#        'commission': 2.0,
#        'currency': 'USD'}},
#      'time': '2024-05-22T15:20:11+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T15:20:11+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18837.75'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 450724771,
#      'action': 'BUY',
#      'orderType': 'LMT',
#      'lmtPrice': 18824.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d40a3.01.01',
#        'time': '2024-05-22T14:05:39+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18824.5,
#        'permId': 450724771,
#        'cumQty': 1.0,
#        'avgPrice': 18824.5,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d40a3.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': -90.150761}},
#      'time': '2024-05-22T14:05:39+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T14:05:39+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18824.5'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 450724772,
#      'action': 'SELL',
#      'orderType': 'LMT',
#      'lmtPrice': 18827.0,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaGroup': '450724771',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder',
#      'parentPermId': 450724771}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d44ef.01.01',
#        'time': '2024-05-22T14:15:33+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'SLD',
#        'shares': 1.0,
#        'price': 18827.0,
#        'permId': 450724772,
#        'cumQty': 1.0,
#        'avgPrice': 18827.0,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d44ef.01.01',
#        'commission': 2.0,
#        'currency': 'USD'}},
#      'time': '2024-05-22T14:15:33+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T14:15:33+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18827.0'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 450724727,
#      'action': 'BUY',
#      'orderType': 'LMT',
#      'lmtPrice': 18820.25,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder'}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d3f93.01.01',
#        'time': '2024-05-22T14:02:40+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'BOT',
#        'shares': 1.0,
#        'price': 18820.25,
#        'permId': 450724727,
#        'cumQty': 1.0,
#        'avgPrice': 18820.25,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d3f93.01.01',
#        'commission': 2.0,
#        'currency': 'USD',
#        'realizedPNL': -25.534348}},
#      'time': '2024-05-22T14:02:40+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T14:02:40+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18820.25'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 450724728,
#      'action': 'SELL',
#      'orderType': 'LMT',
#      'lmtPrice': 18823.25,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaGroup': '450724727',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True,
#      'autoCancelDate': '20240930 16:00:00 Central Standard Time',
#      'filledQuantity': 1.0,
#      'refFuturesConId': 2147483647,
#      'shareholder': 'Not an insider or substantial shareholder',
#      'parentPermId': 450724727}},
#    'orderStatus': {'OrderStatus': {'status': 'Filled'}},
#    'fills': [{'contract': {'Future': {'secType': 'FUT',
#        'conId': 620730920,
#        'symbol': 'NQ',
#        'lastTradeDateOrContractMonth': '20240621',
#        'right': '?',
#        'multiplier': '20',
#        'exchange': 'CME',
#        'currency': 'USD',
#        'localSymbol': 'NQM4',
#        'tradingClass': 'NQ'}},
#      'execution': {'Execution': {'execId': '0000d94c.664d407d.01.01',
#        'time': '2024-05-22T14:05:26+00:00',
#        'acctNumber': 'U10394496',
#        'exchange': 'CME',
#        'side': 'SLD',
#        'shares': 1.0,
#        'price': 18823.25,
#        'permId': 450724728,
#        'cumQty': 1.0,
#        'avgPrice': 18823.25,
#        'lastLiquidity': 1}},
#      'commissionReport': {'CommissionReport': {'execId': '0000d94c.664d407d.01.01',
#        'commission': 2.0,
#        'currency': 'USD'}},
#      'time': '2024-05-22T14:05:26+00:00'}],
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T14:05:26+00:00',
#       'status': 'Filled',
#       'message': 'Fill 1.0@18823.25'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'orderId': 113,
#      'clientId': 2,
#      'permId': 390987485,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18711.25,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'adjustedOrderType': 'None',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True}},
#    'orderStatus': {'OrderStatus': {'orderId': 113,
#      'status': 'Submitted',
#      'remaining': 1.0,
#      'permId': 390987485,
#      'clientId': 2}},
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T20:00:21.897894+00:00',
#       'status': 'Submitted'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 2099801404,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18040.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaGroup': '2099801403',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'adjustedOrderType': 'None',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True}},
#    'orderStatus': {'OrderStatus': {'status': 'Submitted',
#      'remaining': 1.0,
#      'permId': 2099801404}},
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T20:00:21.932142+00:00',
#       'status': 'Submitted'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'orderId': 75,
#      'clientId': 2,
#      'permId': 390987450,
#      'action': 'SELL',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18837.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'adjustedOrderType': 'None',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True}},
#    'orderStatus': {'OrderStatus': {'orderId': 75,
#      'status': 'Submitted',
#      'remaining': 1.0,
#      'permId': 390987450,
#      'clientId': 2}},
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T20:00:21.932142+00:00',
#       'status': 'Submitted'}}]}},
#  {'Trade': {'contract': {'Future': {'secType': 'FUT',
#      'conId': 620730920,
#      'symbol': 'NQ',
#      'lastTradeDateOrContractMonth': '20240621',
#      'right': '?',
#      'multiplier': '20',
#      'exchange': 'CME',
#      'currency': 'USD',
#      'localSymbol': 'NQM4',
#      'tradingClass': 'NQ'}},
#    'order': {'Order': {'permId': 1276830230,
#      'action': 'BUY',
#      'totalQuantity': 1.0,
#      'orderType': 'LMT',
#      'lmtPrice': 18642.5,
#      'auxPrice': 0.0,
#      'tif': 'GTC',
#      'ocaGroup': '1276830229',
#      'ocaType': 3,
#      'displaySize': 2147483647,
#      'rule80A': '0',
#      'openClose': '',
#      'volatilityType': 0,
#      'deltaNeutralOrderType': 'None',
#      'referencePriceType': 0,
#      'account': 'U10394496',
#      'clearingIntent': 'IB',
#      'adjustedOrderType': 'None',
#      'softDollarTier': {'SoftDollarTier': {}},
#      'cashQty': 0.0,
#      'dontUseAutoPriceForHedge': True}},
#    'orderStatus': {'OrderStatus': {'status': 'Submitted',
#      'remaining': 1.0,
#      'permId': 1276830230}},
#    'log': [{'TradeLogEntry': {'time': '2024-05-22T20:00:21.932142+00:00',
#       'status': 'Submitted'}}]}}]

# %%
def print_account_summary(ib):
    print("ACCOUNT SUMMARY::\n")
    acct_fields = ib.accountSummary(account="U10394496")

    for f in acct_fields:
        if "DayTrades" not in f.tag:
            print(f.tag, ":", f.value)
    print()


def print_order(o):
    if o is None:
        print()
        return

    order = o.order
    contract = o.contract
    orderStatus = o.orderStatus

    print(f"symbol\tpermId\t\tstatus\t\taction\tfilled\tremaining\tlmtPrice")

    print(
        f"{contract.symbol}\t{order.permId}\t{orderStatus.status}\t{order.action}\t{orderStatus.filled}\t{orderStatus.remaining}\t\t{order.lmtPrice}\t"
    )


def print_orderbook():
    print("NQ Order Book::")
    if ticker is not None and ticker.domBids is not None and ticker.domAsks is not None:
        for i in range(min(len(ticker.domBids), len(ticker.domAsks))):
            bid_size = ticker.domBids[i].size
            bid_price = ticker.domBids[i].price
            ask_price = ticker.domAsks[i].price
            ask_size = ticker.domAsks[i].size
            print(f"{bid_size:>8} {bid_price:>10} | {ask_price:<10} {ask_size:<8}")

    print()


def print_executions():
    fills = [t.fills for t in ib.trades() if t.fills != []]
    executions = [f[0].execution for f in fills]
    print(f"Intraday Executions: {len(executions)}\n")


def print_positions():
    print("POSITIONS::")
    future = [pos for pos in ib.positions()]
    for f in future:
        print(
            f"{f.contract.symbol} {f.position} @ {f.avgCost/float(contract.multiplier)}"
        )
    print()


# print_positions()


def print_openorders():
    orders = ib.openOrders()
    orders.sort(key=lambda order: order.lmtPrice)

    # Order(orderId=658, clientId=3124, permId=342738244, action='SELL', totalQuantity=1.0, orderType='LMT', lmtPrice=17692.5, auxPrice=0.0, tif='GTC', ocaType=3, displaySize=2147483647, rule80A='0', openClose='', volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='U10394496', clearingIntent='IB', adjustedOrderType='None', cashQty=0.0, dontUseAutoPriceForHedge=True)

    print(f"orderId\tpermId\t\taction\ttotalQuantity\tlmtPrice\ttif")
    for order in orders:
        print(
            f"{order.orderId}\t{order.permId}\t{order.orderType}\t{order.action}\t{order.totalQuantity}\t{order.lmtPrice} \t{order.tif}"
        )
    print()


def print_summary():
    print_orderbook()
    print_executions()
    print_openorders()
    print_positions()
    print_account_summary(ib=ib)


print_summary()
# Out:
# NQ Order Book::
#      1.0   18816.75 | 18817.0    2.0
#      5.0    18816.5 | 18817.25   4.0
#      2.0   18816.25 | 18817.5    4.0
#      5.0    18816.0 | 18817.75   5.0
#      7.0   18815.75 | 18818.0    7.0
#
# Intraday Executions: 92
#
# orderId	permId		action	totalQuantity	lmtPrice	tif
# 0	2099801404	LMT	BUY	1.0	18040.5 	GTC
# 0	1276830230	LMT	BUY	1.0	18642.5 	GTC
# 113	390987485	LMT	BUY	1.0	18711.25 	GTC
# 75	390987450	LMT	SELL	1.0	18837.5 	GTC
#
# POSITIONS::
# BA 254.0 @ 10.1605561025
# EDV 650.0 @ 3.885403845
# RSX 100.0 @ 0.34449885
# HYG 50.0 @ 0.6223425
# AAPL 4.0 @ 9.109842500000001
# QQQ 1.0 @ 25.051845
# NVDA 2.0 @ 17.471155
# GOOGL 10.0 @ 2.5723425
# PINS 40.0 @ 0.6723425
# NQ -2.0 @ 18718.75610406
# NVDA 1.0 @ 25.051845
# QQQ 2.0 @ 10.384842500000001
# AMZN 4.0 @ 5.7843425
#
# ACCOUNT SUMMARY::
#
# AccountType : INDIVIDUAL
# Cushion : 0.695787
# LookAheadNextChange : 1716408000
# AccruedCash : 7.70
# AvailableFunds : 41142.97
# BuyingPower : 293096.07
# EquityWithLoanValue : 73274.02
# ExcessLiquidity : 73274.02
# FullAvailableFunds : 41142.97
# FullExcessLiquidity : 60208.61
# FullInitMarginReq : 47906.50
# FullMaintMarginReq : 43551.36
# GrossPositionValue : 1543.35
# InitMarginReq : 33534.55
# LookAheadAvailableFunds : 41142.97
# LookAheadExcessLiquidity : 60208.61
# LookAheadInitMarginReq : 47906.50
# LookAheadMaintMarginReq : 43551.36
# MaintMarginReq : 30485.95
# NetLiquidation : 105311.02
# PreviousDayEquityWithLoanValue : 0.00
# RegTEquity : 7.70
# RegTMargin : 0.00
# SMA : 622872.02
# TotalCashValue : 103759.97

# %%
# t = ib.openTrades()
# o = ib.openOrders()
clear_output(wait=True)
util.tree(ib.openTrades()[0])
# ib.openTrades()[1]

# %%
clear_output(wait=True)
trade = ib.openTrades()[0]
print(
    f"#{trade.order.permId} {trade.orderStatus.status} {trade.contract.symbol} {trade.order.action} {trade.orderStatus.filled}/{trade.orderStatus.remaining} @ {trade.order.lmtPrice}"
)

# %%
def run_strategy(strategy_details, open_permId, close_permId, cancel_permids=[]):

    push_msg("SESSION STARTED")
    push_msg(f"{strategy_details} / {open_permId} / {close_permId} / {cancel_permids}")

    open_trade = None
    close_trade = None
    open_order = None
    close_order = None
    open_order_ts = None

    if open_permId is not None:
        orders = ib.openOrders()
        for o in orders:
            if o.permId == open_permId:
                open_order = o

    push_msg(f"OPEN ORDER:: {open_order}")

    if open_trade is None:
        trades = ib.trades()
        for o in trades:
            if o.orderStatus.permId == open_permId:
                open_trade = o

    # push_msg(f"OPEN TRADE:: {open_trade.order}")

    if close_permId is not None:
        for o in orders:
            if o.permId == close_permId:
                close_order = o

    push_msg(f"CLOSE ORDER:: {close_order}")

    if close_trade is None:
        trades = ib.trades()
        for o in trades:
            if o.orderStatus.permId == close_permId:
                close_trade = o

    # print(f"CLOSE TRADE:: {close_trade}")

    ib.sleep(3)

    for permId in cancel_permids:
        cancelled_order = None
        for o in orders:
            if o.permId == permId:
                print("Cancelling order.permId {o.permId}")
                cancelled_order = ib.cancelOrder(o)
                ib.sleep(2)
                if cancelled_order.orderStatus.status == "Cancelled":
                    print(f"Order {o.permId} has been cancelled")
                else:
                    raise Exception("Unable to cancel order {o.permId}")

        if cancelled_order is None:
            print("Order not found {permId}")

    while True:
        clear_output(wait=True)

        # first order of the strategy
        if open_trade is None and close_trade is None:
            action = strategy_details["open_action"]
            qty = strategy_details["open_qty"]

            if strategy_details["open_ref"] == "bid":
                price_ref = ticker.domBids[0].price
            elif strategy_details["open_ref"] == "ask":
                price_ref = ticker.domAsks[0].price
            elif strategy_details["open_ref"] == "mid":
                price_ref = (ticker.domAsks[0].price + ticker.domBids[0].price) / 2
            elif strategy_details["open_ref"] == "last":
                raise Exception("Not implemented")

            lmtPrice = (
                price_ref
                + strategy_details["open_ticks"] * strategy_details["tick_increment"]
            )
            print(
                f"Placing open trade: {action}, {strategy_details['open_type']}, totalQuantity {qty}, lmtPrice {lmtPrice}\n"
            )
            print()

            if strategy_details["open_type"] == "LIMIT":
                open_order = LimitOrder(
                    action=action,
                    totalQuantity=qty,
                    lmtPrice=lmtPrice,
                    account="U10394496",
                )
            else:
                raise Exception("Not implemented")

            open_trade = ib.placeOrder(contract, open_order)
            trade = open_trade
            # push_msg(msg=f"OPEN ORDER PLACED:: {close_trade.order}")

            push_msg(
                f"OPEN ORDER PLACED :: #{trade.order.permId} {trade.orderStatus.status} {trade.contract.symbol} {trade.order.action} {trade.orderStatus.filled}/{trade.orderStatus.remaining} @ {trade.order.lmtPrice}"
            )

            open_order_ts = datetime.datetime.now()

        print("OPEN ORDER::")
        print_order(open_trade)
        print()

        if open_trade is not None:
            if open_trade.orderStatus.status == "Submitted" and close_trade is None:
                print(
                    f"Waiting to get filled on order #{open_trade.order.permId} ({open_trade.orderStatus.status})\n"
                )

                if (
                    open_order_ts is None
                    or datetime.datetime.now() - open_order_ts
                    > datetime.timedelta(seconds=strategy_details["pause_seconds"])
                ):
                    print("Cancelling order due to timeout:")
                    ib.cancelOrder(open_trade.order)
                    print()

            if open_trade.orderStatus.status == "Filled" and close_trade is None:
                print(
                    "Filled on open_trade {open_trade.orderStatus.status} {open_trade.orderStatus.avgFillPrice} {open_trade.orderStatus.status}"
                )
                chime.info()
                push_msg(msg=f"OPEN ORDER FILLED:: {open_trade.order}")

                action = strategy_details["close_action"]
                qty = strategy_details["close_qty"]

                if strategy_details["close_ref"] == "open_price_fill":
                    price_ref = open_trade.orderStatus.avgFillPrice
                if strategy_details["close_ref"] == "bid":
                    price_ref = ticker.domBids[0].price
                elif strategy_details["close_ref"] == "ask":
                    price_ref = ticker.domAsks[0].price
                elif strategy_details["close_ref"] == "mid":
                    price_ref = (ticker.domAsks[0].price + ticker.domBids[0].price) / 2
                elif strategy_details["close_ref"] == "last":
                    raise Exception("Not implemented")

                lmtPrice = (
                    price_ref
                    + strategy_details["close_ticks"]
                    * strategy_details["tick_increment"]
                )

                if strategy_details["close_type"] == "LIMIT":
                    close_order = LimitOrder(
                        action=action,
                        totalQuantity=qty,
                        lmtPrice=lmtPrice,
                        account="U10394496",
                    )
                else:
                    raise Exception("Not implemented")

                close_trade = ib.placeOrder(contract, close_order)
                push_msg(msg=f"CLOSE ORDER PLACED:: {close_trade.order}")

            elif (
                open_trade.orderStatus.status == "Inactive"
                or open_trade.orderStatus.status == "Cancelled"
            ) and close_trade is None:
                push_msg(f"OPEN TRADE CANCELLED:: {open_trade.order}")
                open_trade = None

        print(f"CLOSE ORDER::")
        print_order(close_trade)
        print()

        if close_trade is not None:
            if close_trade.orderStatus.status == "Filled":
                print(
                    "Close trade filled @ {}\n".format(
                        close_trade.orderStatus.avgFillPrice
                    )
                )
                chime.success()
                push_msg(f"CLOSE TRADE FILLED:: {close_trade.order}")

                open_trade = None
                close_trade = None
                ib.accountSummary()
                print("ALL OPEN ORDERS::")
                print_openorders()
                print_orderbook()
                print_executions()
                print_positions()
                print_account_summary(ib=ib)

                ib.sleep(strategy_details["pause_seconds"])

        print("ALL OPEN ORDERS::")
        print_openorders()
        print_orderbook()
        print_executions()
        print_positions()
        print_account_summary(ib=ib)

        ib.sleep(1)


sell_scalp = {
    "strategy": "SELL TO OPEN SCALP",
    "contract": "NQM2024",
    "tick_increment": 0.25,
    "open_qty": 1,
    "open_type": "LIMIT",
    "open_action": "SELL",
    "open_ref": "ask",
    "open_ticks": 10,
    "close_qty": 1,
    "close_type": "LIMIT",
    "close_action": "BUY",
    "close_ref": "open_price_fill",
    "close_ticks": -10,
    "pause_seconds": 60,
}

buy_scalp = {
    "strategy": "BUY TO OPEN SCALP",
    "contract": "NQM2024",
    "tick_increment": 0.25,
    "open_qty": 1,
    "open_type": "LIMIT",
    "open_action": "BUY",
    "open_ref": "bid",
    "open_ticks": -2,
    "close_qty": 1,
    "close_type": "LIMIT",
    "close_action": "SELL",
    "close_ref": "open_price_fill",
    "close_ticks": 10,
    "pause_seconds": 90,
}

run_strategy(
    strategy_details=sell_scalp,
    open_permId=262255345,
    close_permId=262255346,
    cancel_permids=[],
)
# Out:
# OPEN ORDER::
# symbol	permId		status		action	filled	remaining	lmtPrice
# NQ	262255345	Filled	SELL	1.0	0.0		18851.0
#
# CLOSE ORDER::
# symbol	permId		status		action	filled	remaining	lmtPrice
# NQ	262255346	Submitted	BUY	0.0	1.0		18846.0
#
# ALL OPEN ORDERS::
# orderId	permId		action	totalQuantity	lmtPrice	tif
# 0	2099801404	LMT	BUY	1.0	18040.5 	GTC
# 0	1276830230	LMT	BUY	1.0	18642.5 	GTC
# 113	390987485	LMT	BUY	1.0	18711.25 	GTC
# 141	262255308	LMT	BUY	1.0	18768.75
# 75	390987450	LMT	SELL	1.0	18837.5 	GTC
# 179	262255346	LMT	BUY	1.0	18846.0
#
# NQ Order Book::
#      2.0    18865.0 | 18865.5    1.0
#      5.0   18864.75 | 18865.75   4.0
#      3.0    18864.5 | 18866.0    4.0
#      5.0   18864.25 | 18866.25   3.0
#      5.0    18864.0 | 18866.5    5.0
#
# Intraday Executions: 116
#
# POSITIONS::
# BA 254.0 @ 10.1605561025
# EDV 650.0 @ 3.885403845
# RSX 100.0 @ 0.34449885
# HYG 50.0 @ 0.6223425
# AAPL 4.0 @ 9.109842500000001
# QQQ 1.0 @ 25.051845
# NVDA 2.0 @ 17.471155
# GOOGL 10.0 @ 2.5723425
# PINS 40.0 @ 0.6723425
# NQ -4.0 @ 18836.693425485
# NVDA 1.0 @ 25.051845
# QQQ 2.0 @ 10.384842500000001
# AMZN 4.0 @ 5.7843425
#
# ACCOUNT SUMMARY::
#
# AccountType : INDIVIDUAL
# Cushion : 0.140206
# LookAheadNextChange : 1716471000
# AccruedCash : 7.70
# AvailableFunds : 5751.24
# BuyingPower : 58014.66
# EquityWithLoanValue : 14503.66
# ExcessLiquidity : 14503.66
# FullAvailableFunds : 5751.24
# FullExcessLiquidity : 14503.66
# FullInitMarginReq : 96276.62
# FullMaintMarginReq : 87524.20
# GrossPositionValue : 1409.52
# InitMarginReq : 96276.62
# LookAheadAvailableFunds : 34634.23
# LookAheadExcessLiquidity : 40760.92
# LookAheadInitMarginReq : 67393.63
# LookAheadMaintMarginReq : 61266.94
# MaintMarginReq : 87524.20
# NetLiquidation : 103445.09
# PreviousDayEquityWithLoanValue : 0.00
# RegTEquity : 7.70
# RegTMargin : 0.00
# SMA : 622874.16
# TotalCashValue : 102027.86
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 242
#     208 sell_scalp = {
#     209     "strategy": "SELL TO OPEN SCALP",
#     210     "contract": "NQM2024",
#    (...)
#     222     "pause_seconds": 60,
#     223 }
#     225 buy_scalp = {
#     226     "strategy": "BUY TO OPEN SCALP",
#     227     "contract": "NQM2024",
#    (...)
#     239     "pause_seconds": 90,
#     240 }
# --> 242 run_strategy(
#     243     strategy_details=sell_scalp,
#     244     open_permId=262255345,
#     245     close_permId=262255346,
#     246     cancel_permids=[],
#     247 )
#
# Cell In[16], line 205, in run_strategy(strategy_details, open_permId, close_permId, cancel_permids)
#     202 print_positions()
#     203 print_account_summary(ib=ib)
# --> 205 ib.sleep(1)
#
# File ~/ib_async/.venv/lib/python3.12/site-packages/ib_async/util.py:402, in sleep(secs)
#     394 def sleep(secs: float = 0.02) -> bool:
#     395     """
#     396     Wait for the given amount of seconds while everything still keeps
#     397     processing in the background. Never use time.sleep().
#    (...)
#     400         secs (float): Time in seconds to wait.
#     401     """
# --> 402     run(asyncio.sleep(secs))
#     403     return True
#
# File ~/ib_async/.venv/lib/python3.12/site-packages/ib_async/util.py:357, in run(timeout, *awaitables)
#     355 globalErrorEvent.connect(onError)
#     356 try:
# --> 357     result = loop.run_until_complete(task)
#     358 except asyncio.CancelledError as e:
#     359     raise globalErrorEvent.value() or e
#
# File ~/ib_async/.venv/lib/python3.12/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/ib_async/.venv/lib/python3.12/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /usr/lib/python3.12/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %%
fills = [t.fills for t in ib.trades() if t.fills != []]
executions = [f[0].execution for f in fills]
util.df(executions)

# %%
from datetime import datetime

input_string = "20240930 16:00:00 Central Standard Time"
date_format = "%Y%m%d %H:%M:%S %Z"

try:
    datetime_object = datetime.strptime(input_string, date_format)
    print(datetime_object)
except ValueError:
    print("Incorrect date format.")

# %%
o

# %%
clear_output()
o = ib.orders()[0]
o = util.dataclassNonDefaults(o)
o.pop("softDollarTier", None)
o.pop("shareholder", None)
o.pop("autoCancelDate", None)
o.pop("auxPrice", None)

data, count = supabase.table("orders").upsert(o).execute()

util.tree(o)

# %%
o["autoCancelDate"]

# %%
od = util.dataclassAsDict(o)
print(od)

# %%
clear_output()
o = ib.orders()[0]
od = util.dataclassAsDict(o)

data, count = supabase.table("orders").upsert(od).execute()

# %%
clear_output()
util.dataclassRepr(ib.trades()[0])

# util.dataclassAsDict(executions[0])

# %%
# Get Account details
details = ib.accountSummary()
details_df = util.df(details)

# Tag Values
# tags = details_df['tag'].values.tolist()
# print(tags)

# Set tag values as index
details_df = details_df.set_index("tag")
net_liquidation_value = details_df.loc["NetLiquidation", "value"]
details_df

# %%
util.tree(ib.trades()[0])

# %%
util.tree(ib.openTrades()[0])

# %%
util.tree(ib.openTrades()[1])

# %%
trades = ib.reqAllOpenOrders()

trades.sort(key=lambda trade: trade.order.lmtPrice)

for trade in trades:
    orderstatus = trade.orderStatus
    order = trade.order

    if trade.contract.symbol != "NQ":
        continue

    print(
        f"{trade.contract.symbol}\t{order.permId}\t{orderstatus.status}\t{order.action}\t{orderstatus.filled}\t{orderstatus.remaining}\t\t{order.lmtPrice}\t"
    )

# %%
trades_df = util.df(ib.trades())
trades_df

# %%
import sqlite3

# Create a connection to the SQLite database
conn = sqlite3.connect("trades.db")

# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# Create the "trades" table if it doesn't exist
cursor.execute(
    """
    CREATE TABLE IF NOT EXISTS trades (
        contract TEXT,
        order TEXT,
        orderStatus TEXT,
        fills TEXT,
        log TEXT,
        advancedError TEXT
    )
"""
)

# Convert the DataFrame to a list of tuples
trades_data = trades_df.to_records(index=False).tolist()

# Insert the data into the "trades" table
cursor.executemany(
    """
    INSERT INTO trades (contract, order, orderStatus, fills, log, advancedError)
    VALUES (?, ?, ?, ?, ?, ?)
""",
    trades_data,
)

# Commit the changes and close the connection
conn.commit()
conn.close()

# %%
# get all the trades where fills is not []
fills = trades_df[trades_df.fills.map(len) > 0]

fills_list = list(fills["order"])

# loop through fills and convert each member of this data type to a row in a df
#  Order(permId=253828901, action='BUY', orderType='LMT', lmtPrice=17580.0, auxPrice=0.0, tif='GTC', ocaType=3, displaySize=2147483647, rule80A='0', openClose='', volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='U10394496', clearingIntent='IB', cashQty=0.0, dontUseAutoPriceForHedge=True, autoCancelDate='20240930 16:00:00 Central Standard Time', filledQuantity=1.0, refFuturesConId=2147483647, shareholder='Not an insider or substantial shareholder')
