# %%
from IPython.core.display import HTML
from IPython.display import display, clear_output

display(HTML("<style>.output_subarea { overflow: auto; }</style>"))

import datetime
import random
import os
import pandas as pd
import socket

from supabase import create_client, Client
from ib_async import *

import urllib

hostname = socket.gethostname()
util.logToFile(f"{datetime.datetime.now().strftime('%Y-%m-%d')}-{hostname}.log")
util.startLoop()
util.logToConsole()

if "ib" in globals():
    ib.disconnect()

randint = lambda a=1, b=10: random.randint(a, b)
ib = IB()
ib.connect("127.0.0.1", 4001, randint(1, 99))

import platform

if platform.system() == "Linux":
    import chime


def chime_success():
    if platform.system() == "Linux":
        chime.success()


chime_success()
os.system("say beep")

# setup listeners for ib
# NQM2024 contract
print("Setting contract to NQM2024 symbol / JUN 2024 / Contract(conId=620730920)")
contract = Contract(conId=620730920)
ib.qualifyContracts(contract)

ticker = ib.reqMktDepth(contract)

ib.reqPositions()
ib.reqAccountSummary()
allopenorders = ib.reqAllOpenOrders()

executions = ib.reqExecutions()

ib.accountSummary()
ib.accountValues()
ib.accountValueEvent()


def push_notifications(msg="Hello world!"):
    try:
        body = f"[{datetime.datetime.now()}] {msg}"
        print(body)
        data = urllib.parse.urlencode({"text": body}).encode()
        req = urllib.request.Request(
            "https://api.chanify.net/v1/sender/CICswLUGEiJBQUZIR0pJQ0VVNkxUTlZCMk1DRElCWU1RSlNWMktCS0NFIgIIAQ.vj8gcfxM4jD9Zv0mBMSlFlY51EL_jC5dB8LWdWX1tAs",
            data=data,
        )
        response = urllib.request.urlopen(req)
        response.read()  # Read the response to ensure the request is complete
    except urllib.error.URLError as e:
        print(f"Error sending request: {e.reason}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")


def print_reqOpenOrders():
    print("Session Orders::")
    display(util.df([t.order for t in ib.reqOpenOrders()]))


def print_reqAllOpenOrders():
    print("All Session Orders:")
    display(util.df([t.order for t in ib.reqAllOpenOrders()]))


def print_account_summary(ib):
    print("ACCOUNT SUMMARY::\n")
    acct_fields = ib.accountSummary(account="U10394496")

    for f in acct_fields:
        if "DayTrades" not in f.tag:
            print(f.tag, ":", f.value)
    print()


def print_order(o):
    if o is None:
        print()
        return

    order = o.order
    contract = o.contract
    orderStatus = o.orderStatus

    print(f"symbol\tpermId\t\tstatus\t\taction\tfilled\tremaining\tlmtPrice")

    print(
        f"{contract.symbol}\t{order.permId}\t{orderStatus.status}\t{order.action}\t{orderStatus.filled}\t{orderStatus.remaining}\t\t{order.lmtPrice}\t"
    )


def print_orderbook():
    print("NQ Order Book::")
    if ticker is not None and ticker.domBids is not None and ticker.domAsks is not None:
        for i in range(min(len(ticker.domBids), len(ticker.domAsks))):
            bid_size = ticker.domBids[i].size
            bid_price = ticker.domBids[i].price
            ask_price = ticker.domAsks[i].price
            ask_size = ticker.domAsks[i].size
            print(f"{bid_size:>8} {bid_price:>10} | {ask_price:<10} {ask_size:<8}")

    print()


def print_executions():
    fills = [t.fills for t in ib.trades() if t.fills != []]
    executions = [f[0].execution for f in fills]
    print(f"Intraday Executions: {len(executions)}\n")


def print_positions():
    print("POSITIONS::")
    future = [pos for pos in ib.positions()]
    for f in future:
        print(
            f"{f.contract.symbol} {f.position} @ {f.avgCost/float(contract.multiplier)}"
        )
    print()


def print_summary():
    print_orderbook()
    print_executions()

    print_positions()
    print_account_summary(ib=ib)


def print_openOrders(status_list=["Submitted", "PendingSubmit", "PendingCancel"]):
    print(":: openOrders ::")
    display(util.df([t for t in ib.openOrders()]))


def print_submittedtrades():
    print(":: trades ::")
    display(
        util.df(
            [
                t.order
                for t in ib.trades()
                if t.orderStatus.status == "Submitted"
                or t.orderStatus.status == "PreSubmitted"
                or t.orderStatus.status == "PendingSubmit"
            ]
        )
    )


print_summary()

print_submittedtrades()
# Out:
# <style>.output_subarea { overflow: auto; }</style>
# 2024-05-23 15:29:02,627 ib_async.ib INFO Disconnecting from 127.0.0.1:4001, 882 B sent in 15 messages, 3.44 MB received in 116607 messages, session time 1.93 ks.
# 2024-05-23 15:29:02,632 ib_async.client INFO Disconnecting
# 2024-05-23 15:29:02,639 ib_async.client INFO Disconnected.
# 2024-05-23 15:29:02,648 ib_async.client INFO Connecting to 127.0.0.1:4001 with clientId 83...
# 2024-05-23 15:29:02,655 ib_async.client INFO Connected
# 2024-05-23 15:29:02,677 ib_async.client INFO Logged on to server version 176
# 2024-05-23 15:29:02,687 ib_async.wrapper INFO Warning 2104, reqId -1: Market data farm connection is OK:usfuture
# 2024-05-23 15:29:02,689 ib_async.wrapper INFO Warning 2104, reqId -1: Market data farm connection is OK:usfarm
# 2024-05-23 15:29:02,692 ib_async.wrapper INFO Warning 2107, reqId -1: HMDS data farm connection is inactive but should be available upon demand.ushmds
# 2024-05-23 15:29:02,695 ib_async.wrapper INFO Warning 2158, reqId -1: Sec-def data farm connection is OK:secdefil
# 2024-05-23 15:29:02,697 ib_async.client INFO API connection ready
# 2024-05-23 15:29:02,711 ib_async.wrapper INFO position: Position(account='U2340948', contract=Stock(conId=4762, symbol='BA', exchange='NYSE', currency='USD', localSymbol='BA', tradingClass='BA'), position=254.0, avgCost=203.21112205)
# 2024-05-23 15:29:02,749 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=637079300, symbol='HYG', lastTradeDateOrContractMonth='20240621', strike=73.0, right='P', multiplier='100', currency='USD', localSymbol='HYG   240621P00073000', tradingClass='HYG'), position=50.0, avgCost=12.44685)
# 2024-05-23 15:29:02,750 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=682674010, symbol='AAPL', lastTradeDateOrContractMonth='20241018', strike=150.0, right='P', multiplier='100', currency='USD', localSymbol='AAPL  241018P00150000', tradingClass='AAPL'), position=4.0, avgCost=182.19685)
# 2024-05-23 15:29:02,753 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=657576926, symbol='QQQ', lastTradeDateOrContractMonth='20240930', strike=376.78, right='P', multiplier='100', currency='USD', localSymbol='QQQ   240930P00376780', tradingClass='QQQ'), position=1.0, avgCost=501.0369)
# 2024-05-23 15:29:02,761 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=669333316, symbol='NVDA', lastTradeDateOrContractMonth='20240719', strike=555.0, right='P', multiplier='100', currency='USD', localSymbol='NVDA  240719P00555000', tradingClass='NVDA'), position=2.0, avgCost=349.4231)
# 2024-05-23 15:29:02,768 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=613471094, symbol='GOOGL', lastTradeDateOrContractMonth='20240920', strike=120.0, right='P', multiplier='100', currency='USD', localSymbol='GOOGL 240920P00120000', tradingClass='GOOGL'), position=10.0, avgCost=51.44685)
# 2024-05-23 15:29:02,773 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=699061747, symbol='NVDA', lastTradeDateOrContractMonth='20240719', strike=855.0, right='P', multiplier='100', currency='USD', localSymbol='NVDA  240719P00855000', tradingClass='NVDA'), position=1.0, avgCost=593.04685)
# 2024-05-23 15:29:02,775 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=699536227, symbol='PINS', lastTradeDateOrContractMonth='20240607', strike=33.0, right='P', multiplier='100', currency='USD', localSymbol='PINS  240607P00033000', tradingClass='PINS'), position=40.0, avgCost=13.44685)
# 2024-05-23 15:29:02,777 ib_async.wrapper INFO position: Position(account='U10394496', contract=Future(conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', currency='USD', localSymbol='NQM4', tradingClass='NQ'), position=1.0, avgCost=373674.78033355)
# 2024-05-23 15:29:02,779 ib_async.wrapper INFO position: Position(account='U2340948', contract=Stock(conId=47486780, symbol='EDV', exchange='ARCA', currency='USD', localSymbol='EDV', tradingClass='EDV'), position=650.0, avgCost=77.7080769)
# 2024-05-23 15:29:02,780 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=642744523, symbol='NVDA', lastTradeDateOrContractMonth='20240920', strike=510.0, right='P', multiplier='100', currency='USD', localSymbol='NVDA  240920P00510000', tradingClass='NVDA'), position=1.0, avgCost=501.0369)
# 2024-05-23 15:29:02,781 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=699532596, symbol='QQQ', lastTradeDateOrContractMonth='20240607', strike=400.0, right='P', multiplier='100', currency='USD', localSymbol='QQQ   240607P00400000', tradingClass='QQQ'), position=2.0, avgCost=207.69685)
# 2024-05-23 15:29:02,784 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=682677111, symbol='AMZN', lastTradeDateOrContractMonth='20241018', strike=130.0, right='P', multiplier='100', currency='USD', localSymbol='AMZN  241018P00130000', tradingClass='AMZN'), position=4.0, avgCost=115.68685)
# 2024-05-23 15:29:02,789 ib_async.wrapper INFO position: Position(account='U2340948', contract=Stock(conId=229726228, symbol='RSX', exchange='VALUE', currency='USD', localSymbol='RSX', tradingClass='RSX'), position=100.0, avgCost=6.889977)
# 2024-05-23 15:29:03,565 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e8040.01.01', time=datetime.datetime(2024, 5, 23, 10, 58, 57, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18970.5, permId=1394515163, clientId=1, orderId=285, liquidation=0, cumQty=1.0, avgPrice=18970.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,606 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e852d.01.01', time=datetime.datetime(2024, 5, 23, 12, 29, 56, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=19002.75, permId=196158470, clientId=69, orderId=187, liquidation=0, cumQty=1.0, avgPrice=19002.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,615 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e8581.01.01', time=datetime.datetime(2024, 5, 23, 12, 30, 52, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=19005.25, permId=196158471, clientId=69, orderId=188, liquidation=0, cumQty=1.0, avgPrice=19005.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,618 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e8687.01.01', time=datetime.datetime(2024, 5, 23, 12, 35, 59, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=19014.25, permId=196158474, clientId=69, orderId=191, liquidation=0, cumQty=1.0, avgPrice=19014.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,623 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e8746.01.01', time=datetime.datetime(2024, 5, 23, 12, 42, 9, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=19016.75, permId=196158475, clientId=69, orderId=192, liquidation=0, cumQty=1.0, avgPrice=19016.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,628 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e87f7.01.01', time=datetime.datetime(2024, 5, 23, 12, 47, 36, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=19019.25, permId=196158478, clientId=69, orderId=195, liquidation=0, cumQty=1.0, avgPrice=19019.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,631 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e9c15.01.01', time=datetime.datetime(2024, 5, 23, 13, 45, 29, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18925.0, permId=196158480, clientId=69, orderId=197, liquidation=0, cumQty=1.0, avgPrice=18925.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,636 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e9c6a.01.01', time=datetime.datetime(2024, 5, 23, 13, 45, 47, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18927.5, permId=196158481, clientId=69, orderId=198, liquidation=0, cumQty=1.0, avgPrice=18927.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,640 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e9d48.01.01', time=datetime.datetime(2024, 5, 23, 13, 47, 20, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18916.5, permId=196158482, clientId=69, orderId=199, liquidation=0, cumQty=1.0, avgPrice=18916.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,653 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e9d63.01.01', time=datetime.datetime(2024, 5, 23, 13, 47, 28, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18919.0, permId=196158483, clientId=69, orderId=200, liquidation=0, cumQty=1.0, avgPrice=18919.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,661 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e9f50.01.01', time=datetime.datetime(2024, 5, 23, 13, 49, 12, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18896.5, permId=196158484, clientId=69, orderId=201, liquidation=0, cumQty=1.0, avgPrice=18896.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,667 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e9f5d.01.01', time=datetime.datetime(2024, 5, 23, 13, 49, 16, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18899.0, permId=196158485, clientId=69, orderId=202, liquidation=0, cumQty=1.0, avgPrice=18899.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,669 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ea0fc.01.01', time=datetime.datetime(2024, 5, 23, 13, 50, 51, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18884.75, permId=196158486, clientId=69, orderId=203, liquidation=0, cumQty=1.0, avgPrice=18884.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,670 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ea12b.01.01', time=datetime.datetime(2024, 5, 23, 13, 50, 59, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18887.25, permId=196158487, clientId=69, orderId=204, liquidation=0, cumQty=1.0, avgPrice=18887.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,672 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ea3db.01.01', time=datetime.datetime(2024, 5, 23, 13, 52, 39, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18865.25, permId=196158488, clientId=69, orderId=205, liquidation=0, cumQty=1.0, avgPrice=18865.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,673 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ea3f0.01.01', time=datetime.datetime(2024, 5, 23, 13, 52, 46, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18867.75, permId=196158489, clientId=69, orderId=206, liquidation=0, cumQty=1.0, avgPrice=18867.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,675 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ea522.01.01', time=datetime.datetime(2024, 5, 23, 13, 54, 25, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18851.5, permId=196158490, clientId=69, orderId=207, liquidation=0, cumQty=1.0, avgPrice=18851.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,677 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ea568.01.01', time=datetime.datetime(2024, 5, 23, 13, 54, 36, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18854.0, permId=196158491, clientId=69, orderId=208, liquidation=0, cumQty=1.0, avgPrice=18854.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,679 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ea683.01.01', time=datetime.datetime(2024, 5, 23, 13, 56, 10, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18858.75, permId=196158492, clientId=69, orderId=209, liquidation=0, cumQty=1.0, avgPrice=18858.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,680 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ea703.01.01', time=datetime.datetime(2024, 5, 23, 13, 56, 51, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18846.0, permId=262255346, clientId=5, orderId=179, liquidation=0, cumQty=1.0, avgPrice=18846.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,682 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ea963.01.01', time=datetime.datetime(2024, 5, 23, 13, 59, 38, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18846.25, permId=196158494, clientId=69, orderId=211, liquidation=0, cumQty=1.0, avgPrice=18846.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,684 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ea9d7.01.01', time=datetime.datetime(2024, 5, 23, 14, 0, 4, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18861.25, permId=196158493, clientId=69, orderId=210, liquidation=0, cumQty=1.0, avgPrice=18861.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,685 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eac09.01.01', time=datetime.datetime(2024, 5, 23, 14, 1, 41, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18876.75, permId=196158496, clientId=69, orderId=213, liquidation=0, cumQty=1.0, avgPrice=18876.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,687 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eb14f.01.01', time=datetime.datetime(2024, 5, 23, 14, 9, 22, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18879.25, permId=196158497, clientId=69, orderId=214, liquidation=0, cumQty=1.0, avgPrice=18879.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,690 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eb314.01.01', time=datetime.datetime(2024, 5, 23, 14, 10, 54, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18896.0, permId=196158498, clientId=69, orderId=215, liquidation=0, cumQty=1.0, avgPrice=18896.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,692 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eb339.01.01', time=datetime.datetime(2024, 5, 23, 14, 11, 5, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18898.5, permId=196158499, clientId=69, orderId=216, liquidation=0, cumQty=1.0, avgPrice=18898.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,693 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eb522.01.01', time=datetime.datetime(2024, 5, 23, 14, 14, 28, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18898.0, permId=196158501, clientId=69, orderId=218, liquidation=0, cumQty=1.0, avgPrice=18898.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,694 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eb52d.01.01', time=datetime.datetime(2024, 5, 23, 14, 14, 36, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18900.5, permId=196158502, clientId=69, orderId=219, liquidation=0, cumQty=1.0, avgPrice=18900.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,696 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eb63a.01.01', time=datetime.datetime(2024, 5, 23, 14, 16, 10, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18906.0, permId=196158503, clientId=69, orderId=220, liquidation=0, cumQty=1.0, avgPrice=18906.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,698 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eb64f.01.01', time=datetime.datetime(2024, 5, 23, 14, 16, 16, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18908.5, permId=196158504, clientId=69, orderId=221, liquidation=0, cumQty=1.0, avgPrice=18908.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,699 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eb84a.01.01', time=datetime.datetime(2024, 5, 23, 14, 18, 17, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18889.25, permId=196158505, clientId=69, orderId=222, liquidation=0, cumQty=1.0, avgPrice=18889.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,701 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eb85a.01.01', time=datetime.datetime(2024, 5, 23, 14, 18, 24, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18891.75, permId=196158506, clientId=69, orderId=223, liquidation=0, cumQty=1.0, avgPrice=18891.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,702 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eb917.01.01', time=datetime.datetime(2024, 5, 23, 14, 20, 14, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18888.75, permId=196158507, clientId=69, orderId=224, liquidation=0, cumQty=1.0, avgPrice=18888.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,704 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ebe4a.01.01', time=datetime.datetime(2024, 5, 23, 14, 29, 4, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18891.25, permId=196158508, clientId=69, orderId=225, liquidation=0, cumQty=1.0, avgPrice=18891.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,707 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ebf7b.01.01', time=datetime.datetime(2024, 5, 23, 14, 30, 38, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18876.25, permId=196158509, clientId=69, orderId=226, liquidation=0, cumQty=1.0, avgPrice=18876.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,709 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ebfb4.01.01', time=datetime.datetime(2024, 5, 23, 14, 31, 4, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18878.75, permId=196158510, clientId=69, orderId=227, liquidation=0, cumQty=1.0, avgPrice=18878.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,710 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ec10f.01.01', time=datetime.datetime(2024, 5, 23, 14, 32, 54, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18902.5, permId=196158511, clientId=69, orderId=228, liquidation=0, cumQty=1.0, avgPrice=18902.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,712 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ec226.01.01', time=datetime.datetime(2024, 5, 23, 14, 36, 22, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18905.0, permId=196158512, clientId=69, orderId=229, liquidation=0, cumQty=1.0, avgPrice=18905.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,713 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ec2bf.01.01', time=datetime.datetime(2024, 5, 23, 14, 38, 8, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18905.0, permId=196158513, clientId=69, orderId=230, liquidation=0, cumQty=1.0, avgPrice=18905.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,714 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ec30e.01.01', time=datetime.datetime(2024, 5, 23, 14, 39, 23, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18907.5, permId=196158514, clientId=69, orderId=231, liquidation=0, cumQty=1.0, avgPrice=18907.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,716 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ec3e8.01.01', time=datetime.datetime(2024, 5, 23, 14, 40, 56, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18909.75, permId=196158515, clientId=69, orderId=232, liquidation=0, cumQty=1.0, avgPrice=18909.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,718 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eca8b.01.01', time=datetime.datetime(2024, 5, 23, 14, 53, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18843.75, permId=196158495, clientId=69, orderId=212, liquidation=0, cumQty=1.0, avgPrice=18843.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,719 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eceb9.01.01', time=datetime.datetime(2024, 5, 23, 14, 57, 6, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18811.5, permId=196158517, clientId=69, orderId=234, liquidation=0, cumQty=1.0, avgPrice=18811.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,723 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ecf25.01.01', time=datetime.datetime(2024, 5, 23, 14, 57, 47, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18809.0, permId=196158518, clientId=69, orderId=235, liquidation=0, cumQty=1.0, avgPrice=18809.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,726 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ed020.01.01', time=datetime.datetime(2024, 5, 23, 14, 58, 53, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18806.75, permId=196158519, clientId=69, orderId=236, liquidation=0, cumQty=1.0, avgPrice=18806.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,728 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ed026.01.01', time=datetime.datetime(2024, 5, 23, 14, 58, 57, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18804.25, permId=196158520, clientId=69, orderId=237, liquidation=0, cumQty=1.0, avgPrice=18804.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,729 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ed0ad.01.01', time=datetime.datetime(2024, 5, 23, 15, 0, 1, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18809.5, permId=196158521, clientId=69, orderId=238, liquidation=0, cumQty=1.0, avgPrice=18809.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,731 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ed0b4.01.01', time=datetime.datetime(2024, 5, 23, 15, 0, 2, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18807.0, permId=196158522, clientId=69, orderId=239, liquidation=0, cumQty=1.0, avgPrice=18807.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,733 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ed1f7.01.01', time=datetime.datetime(2024, 5, 23, 15, 1, 3, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18832.0, permId=196158523, clientId=69, orderId=240, liquidation=0, cumQty=1.0, avgPrice=18832.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,734 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ed234.01.01', time=datetime.datetime(2024, 5, 23, 15, 1, 21, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18829.5, permId=196158524, clientId=69, orderId=241, liquidation=0, cumQty=1.0, avgPrice=18829.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,736 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ed36a.01.01', time=datetime.datetime(2024, 5, 23, 15, 2, 42, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18844.75, permId=196158525, clientId=69, orderId=242, liquidation=0, cumQty=1.0, avgPrice=18844.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,737 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ed370.01.01', time=datetime.datetime(2024, 5, 23, 15, 2, 44, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18842.25, permId=196158526, clientId=69, orderId=243, liquidation=0, cumQty=1.0, avgPrice=18842.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,740 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ed3f6.01.01', time=datetime.datetime(2024, 5, 23, 15, 3, 47, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18840.0, permId=196158527, clientId=69, orderId=244, liquidation=0, cumQty=1.0, avgPrice=18840.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,743 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ed4a9.01.01', time=datetime.datetime(2024, 5, 23, 15, 5, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18837.5, permId=196158528, clientId=69, orderId=245, liquidation=0, cumQty=1.0, avgPrice=18837.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,744 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ed51a.01.01', time=datetime.datetime(2024, 5, 23, 15, 6, 14, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18838.0, permId=196158529, clientId=69, orderId=246, liquidation=0, cumQty=1.0, avgPrice=18838.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,746 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee124.01.01', time=datetime.datetime(2024, 5, 23, 15, 37, 5, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18912.25, permId=196158516, clientId=69, orderId=233, liquidation=0, cumQty=1.0, avgPrice=18912.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,747 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee43e.01.01', time=datetime.datetime(2024, 5, 23, 15, 45, 36, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18911.75, permId=196158531, clientId=69, orderId=248, liquidation=0, cumQty=1.0, avgPrice=18911.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,748 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee46a.01.01', time=datetime.datetime(2024, 5, 23, 15, 46, 18, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18914.25, permId=196158532, clientId=69, orderId=249, liquidation=0, cumQty=1.0, avgPrice=18914.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,753 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee4e7.01.01', time=datetime.datetime(2024, 5, 23, 15, 48, 23, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18910.0, permId=196158533, clientId=69, orderId=250, liquidation=0, cumQty=1.0, avgPrice=18910.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,760 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee4ed.01.01', time=datetime.datetime(2024, 5, 23, 15, 48, 28, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18912.5, permId=196158534, clientId=69, orderId=251, liquidation=0, cumQty=1.0, avgPrice=18912.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,763 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee683.01.01', time=datetime.datetime(2024, 5, 23, 15, 53, 41, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18922.0, permId=196158537, clientId=69, orderId=254, liquidation=0, cumQty=1.0, avgPrice=18922.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,766 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee68d.01.01', time=datetime.datetime(2024, 5, 23, 15, 53, 46, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18924.5, permId=196158538, clientId=69, orderId=255, liquidation=0, cumQty=1.0, avgPrice=18924.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,768 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee71c.01.01', time=datetime.datetime(2024, 5, 23, 15, 55, 39, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18924.0, permId=196158539, clientId=69, orderId=256, liquidation=0, cumQty=1.0, avgPrice=18924.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,769 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee720.01.01', time=datetime.datetime(2024, 5, 23, 15, 55, 43, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18926.5, permId=196158540, clientId=69, orderId=257, liquidation=0, cumQty=1.0, avgPrice=18926.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,771 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee7b3.01.01', time=datetime.datetime(2024, 5, 23, 15, 57, 27, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18922.5, permId=196158541, clientId=69, orderId=258, liquidation=0, cumQty=1.0, avgPrice=18922.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,778 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee7d3.01.01', time=datetime.datetime(2024, 5, 23, 15, 57, 48, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18925.0, permId=196158542, clientId=69, orderId=259, liquidation=0, cumQty=1.0, avgPrice=18925.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,779 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee85c.01.01', time=datetime.datetime(2024, 5, 23, 15, 59, 22, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18916.5, permId=196158543, clientId=69, orderId=260, liquidation=0, cumQty=1.0, avgPrice=18916.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,781 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ee93f.01.01', time=datetime.datetime(2024, 5, 23, 16, 0, 54, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18919.0, permId=196158544, clientId=69, orderId=261, liquidation=0, cumQty=1.0, avgPrice=18919.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,782 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eea2e.01.01', time=datetime.datetime(2024, 5, 23, 16, 3, 13, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18924.25, permId=196158545, clientId=69, orderId=262, liquidation=0, cumQty=1.0, avgPrice=18924.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,784 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ef200.01.01', time=datetime.datetime(2024, 5, 23, 16, 30, 8, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18926.75, permId=196158546, clientId=69, orderId=263, liquidation=0, cumQty=1.0, avgPrice=18926.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,786 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ef2ac.01.01', time=datetime.datetime(2024, 5, 23, 16, 33, 31, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18922.0, permId=196158548, clientId=69, orderId=265, liquidation=0, cumQty=1.0, avgPrice=18922.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,789 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ef2d2.01.01', time=datetime.datetime(2024, 5, 23, 16, 34, 2, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18924.5, permId=196158549, clientId=69, orderId=266, liquidation=0, cumQty=1.0, avgPrice=18924.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,790 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ef35d.01.01', time=datetime.datetime(2024, 5, 23, 16, 35, 40, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18921.0, permId=196158550, clientId=69, orderId=267, liquidation=0, cumQty=1.0, avgPrice=18921.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,791 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ef373.01.01', time=datetime.datetime(2024, 5, 23, 16, 36, 6, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18923.5, permId=196158551, clientId=69, orderId=268, liquidation=0, cumQty=1.0, avgPrice=18923.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,793 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664ef3d2.01.01', time=datetime.datetime(2024, 5, 23, 16, 39, 16, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18922.0, permId=196158553, clientId=69, orderId=270, liquidation=0, cumQty=1.0, avgPrice=18922.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,795 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664efd0a.01.01', time=datetime.datetime(2024, 5, 23, 17, 3, 25, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18835.5, permId=196158530, clientId=69, orderId=247, liquidation=0, cumQty=1.0, avgPrice=18835.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,796 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664efe76.01.01', time=datetime.datetime(2024, 5, 23, 17, 6, 3, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18843.5, permId=1735428818, clientId=54, orderId=273, liquidation=0, cumQty=1.0, avgPrice=18843.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,799 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664efe8d.01.01', time=datetime.datetime(2024, 5, 23, 17, 6, 11, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18841.0, permId=1735428819, clientId=54, orderId=274, liquidation=0, cumQty=1.0, avgPrice=18841.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,800 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664efee6.01.01', time=datetime.datetime(2024, 5, 23, 17, 7, 23, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18837.5, permId=1735428975, clientId=54, orderId=275, liquidation=0, cumQty=1.0, avgPrice=18837.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,801 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664efeec.01.01', time=datetime.datetime(2024, 5, 23, 17, 7, 33, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18835.0, permId=1735428976, clientId=54, orderId=276, liquidation=0, cumQty=1.0, avgPrice=18835.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,803 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eff23.01.01', time=datetime.datetime(2024, 5, 23, 17, 8, 37, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18832.75, permId=1735428977, clientId=54, orderId=277, liquidation=0, cumQty=1.0, avgPrice=18832.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,805 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664eff93.01.01', time=datetime.datetime(2024, 5, 23, 17, 10, 31, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18830.25, permId=1735428978, clientId=54, orderId=278, liquidation=0, cumQty=1.0, avgPrice=18830.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,806 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f0000.01.01', time=datetime.datetime(2024, 5, 23, 17, 11, 58, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18841.25, permId=1735428979, clientId=54, orderId=279, liquidation=0, cumQty=1.0, avgPrice=18841.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,807 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f030f.01.01', time=datetime.datetime(2024, 5, 23, 17, 19, 22, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18838.75, permId=1735428980, clientId=54, orderId=280, liquidation=0, cumQty=1.0, avgPrice=18838.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,816 ib_async.wrapper INFO execDetails Execution(execId='0001a6af.664f7418.01.01', time=datetime.datetime(2024, 5, 23, 17, 22, 33, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='PHLX', side='BOT', shares=1.0, price=5.92, permId=1045357709, clientId=0, orderId=0, liquidation=0, cumQty=1.0, avgPrice=5.92, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,824 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f0588.01.01', time=datetime.datetime(2024, 5, 23, 17, 24, 12, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18824.25, permId=1735428982, clientId=54, orderId=283, liquidation=0, cumQty=1.0, avgPrice=18824.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,828 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f058c.01.01', time=datetime.datetime(2024, 5, 23, 17, 24, 18, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18821.75, permId=1735428983, clientId=54, orderId=284, liquidation=0, cumQty=1.0, avgPrice=18821.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,832 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f0662.01.01', time=datetime.datetime(2024, 5, 23, 17, 26, 37, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18829.5, permId=1735428985, clientId=54, orderId=286, liquidation=0, cumQty=1.0, avgPrice=18829.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,837 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f0669.01.01', time=datetime.datetime(2024, 5, 23, 17, 26, 51, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18827.0, permId=1735428986, clientId=54, orderId=287, liquidation=0, cumQty=1.0, avgPrice=18827.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,840 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f0695.01.01', time=datetime.datetime(2024, 5, 23, 17, 27, 56, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18830.5, permId=1735428987, clientId=54, orderId=288, liquidation=0, cumQty=1.0, avgPrice=18830.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,843 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f082c.01.01', time=datetime.datetime(2024, 5, 23, 17, 33, 30, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18828.0, permId=1735428988, clientId=54, orderId=289, liquidation=0, cumQty=1.0, avgPrice=18828.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,845 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f08aa.01.01', time=datetime.datetime(2024, 5, 23, 17, 35, 36, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18831.75, permId=1735428990, clientId=54, orderId=291, liquidation=0, cumQty=1.0, avgPrice=18831.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,850 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f08b0.01.01', time=datetime.datetime(2024, 5, 23, 17, 35, 46, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18829.25, permId=1735428991, clientId=54, orderId=292, liquidation=0, cumQty=1.0, avgPrice=18829.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 15:29:03,851 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f097c.01.01', time=datetime.datetime(2024, 5, 23, 17, 36, 50, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18817.25, permId=1735428992, clientId=54, orderId=293, liquidation=0, cumQty=1.0, avgPrice=18817.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# ...
# 2024-05-23 15:29:05,522 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f2486.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,525 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f248d.01.01', commission=2.0, currency='USD', realizedPNL=-22.546715, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,526 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f24a9.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,527 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3237.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,528 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3430.01.01', commission=2.0, currency='USD', realizedPNL=-1062.023358, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,529 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3495.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,531 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3524.01.01', commission=2.0, currency='USD', realizedPNL=-728.767518, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,531 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3547.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,532 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3676.01.01', commission=2.0, currency='USD', realizedPNL=-553.825639, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,534 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3911.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,535 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3a61.01.01', commission=2.0, currency='USD', realizedPNL=-372.619229, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,536 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3a72.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,538 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3acb.01.01', commission=2.0, currency='USD', realizedPNL=-56.714422, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,541 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3ae2.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,542 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3b69.01.01', commission=2.0, currency='USD', realizedPNL=-259.785816, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,544 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3b74.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,545 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3be5.01.01', commission=2.0, currency='USD', realizedPNL=-132.089362, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,546 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3bea.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,548 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3c14.01.01', commission=2.0, currency='USD', realizedPNL=-156.317022, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,549 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3c99.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,551 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3ce6.01.01', commission=2.0, currency='USD', realizedPNL=75.512234, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,552 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3f0c.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,553 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3f77.01.01', commission=2.0, currency='USD', realizedPNL=219.384175, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,554 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3f85.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,557 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3fe8.01.01', commission=2.0, currency='USD', realizedPNL=197.288131, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,559 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3ff4.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,560 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4084.01.01', commission=2.0, currency='USD', realizedPNL=100.716099, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,561 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f408a.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,562 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f40da.01.01', commission=2.0, currency='USD', realizedPNL=198.287074, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,563 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4109.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,564 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f420e.01.01', commission=2.0, currency='USD', realizedPNL=496.465305, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,566 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4243.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,567 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f42c5.01.01', commission=2.0, currency='USD', realizedPNL=430.098979, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,568 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f45e6.01.01', commission=2.0, currency='USD', realizedPNL=830.098979, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,569 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f45f0.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,570 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4658.01.01', commission=2.0, currency='USD', realizedPNL=437.065986, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,574 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f465d.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,575 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f468b.01.01', commission=2.0, currency='USD', realizedPNL=305.043991, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,576 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f468d.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,577 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f46c6.01.01', commission=2.0, currency='USD', realizedPNL=242.029327, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,579 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f473f.01.01', commission=2.0, currency='USD', realizedPNL=627.029327, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,579 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4885.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,580 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4903.01.01', commission=2.0, currency='USD', realizedPNL=446.514664, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,582 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f491e.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,583 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4968.01.01', commission=2.0, currency='USD', realizedPNL=358.757332, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,585 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4970.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,586 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f49ec.01.01', commission=2.0, currency='USD', realizedPNL=-270.121334, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,587 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f49f2.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,590 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4a7c.01.01', commission=2.0, currency='USD', realizedPNL=-74.560667, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,592 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4caa.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 15:29:05,593 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4cc7.01.01', commission=2.0, currency='USD', realizedPNL=103.219666, yield_=0.0, yieldRedemptionDate=0)
# NQ Order Book::
#      2.0    18689.5 | 18690.0    5.0
#      3.0   18689.25 | 18690.25   5.0
#      1.0    18689.0 | 18690.5    2.0
#      5.0   18688.75 | 18690.75   6.0
#      4.0    18688.5 | 18691.0    6.0
#
# Intraday Executions: 176
#
# POSITIONS::
# BA 254.0 @ 10.1605561025
# EDV 650.0 @ 3.885403845
# RSX 100.0 @ 0.34449885
# HYG 50.0 @ 0.6223425
# AAPL 4.0 @ 9.109842500000001
# QQQ 1.0 @ 25.051845
# NVDA 2.0 @ 17.471155
# GOOGL 10.0 @ 2.5723425
# NVDA 1.0 @ 29.652342499999996
# PINS 40.0 @ 0.6723425
# NQ 1.0 @ 18683.7390166775
# NVDA 1.0 @ 25.051845
# QQQ 2.0 @ 10.384842500000001
# AMZN 4.0 @ 5.7843425
#
# ACCOUNT SUMMARY::
#
# AccountType : INDIVIDUAL
# Cushion : 0.769435
# LookAheadNextChange : 1716557400
# AccruedCash : 7.70
# AvailableFunds : 47781.78
# BuyingPower : 312069.62
# EquityWithLoanValue : 78017.40
# ExcessLiquidity : 78017.40
# FullAvailableFunds : 47781.78
# FullExcessLiquidity : 78017.40
# FullInitMarginReq : 23087.22
# FullMaintMarginReq : 20988.38
# GrossPositionValue : 2382.25
# InitMarginReq : 23087.22
# LookAheadAvailableFunds : 0.00
# LookAheadExcessLiquidity : 84313.92
# LookAheadInitMarginReq : 16161.05
# LookAheadMaintMarginReq : 14691.87
# MaintMarginReq : 20988.38
# NetLiquidation : 101395.73
# PreviousDayEquityWithLoanValue : 0.00
# RegTEquity : 7.70
# RegTMargin : 0.00
# SMA : 622874.16
# TotalCashValue : 99005.78
#
# :: trades ::
#    orderId  clientId      permId action  totalQuantity orderType  lmtPrice  \
# 0      311        54  1735429010   SELL            1.0       LMT  18766.75
# 1      378         6  1735430610    BUY            1.0       LMT  18670.25
# 2      379         6  1735430611    BUY            1.0       LMT  18670.25
# 3        0         0  2099801404    BUY            1.0       LMT  18040.50
# 4      271        69   196158554   SELL            1.0       LMT  18924.50
# 5      401        40  1735431452    BUY            1.0       LMT  18685.25
# 6      196        69   196158479   SELL            1.0       LMT  19021.75
#
#    auxPrice  tif activeStartTime  ... usePriceMgmtAlgo    duration  \
# 0       0.0  GTC                  ...            False  2147483647
# 1       0.0  GTC                  ...            False  2147483647
# 2       0.0  GTC                  ...            False  2147483647
# 3       0.0  GTC                  ...            False  2147483647
# 4       0.0  GTC                  ...            False  2147483647
# 5       0.0  GTC                  ...            False  2147483647
# 6       0.0  GTC                  ...            False  2147483647
#
#     postToAts advancedErrorOverride  manualOrderTime  minTradeQty  \
# 0  2147483647                                          2147483647
# 1  2147483647                                          2147483647
# 2  2147483647                                          2147483647
# 3  2147483647                                          2147483647
# 4  2147483647                                          2147483647
# 5  2147483647                                          2147483647
# 6  2147483647                                          2147483647
#
#    minCompeteSize  competeAgainstBestOffset  midOffsetAtWhole  midOffsetAtHalf
# 0      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 1      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 2      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 3      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 4      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 5      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 6      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
#
# [7 rows x 139 columns]
# 2024-05-23 15:39:55,209 ib_async.wrapper INFO position: Position(account='U10394496', contract=Future(conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', currency='USD', localSymbol='NQM4', tradingClass='NQ'), position=2.0, avgCost=373689.890166775)
# 2024-05-23 15:39:55,218 ib_async.wrapper INFO position: Position(account='U10394496', contract=Future(conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', currency='USD', localSymbol='NQM4', tradingClass='NQ'), position=2.0, avgCost=373690.890166775)
# 2024-05-23 15:44:39,940 ib_async.wrapper INFO position: Position(account='U10394496', contract=Future(conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', currency='USD', localSymbol='NQM4', tradingClass='NQ'), position=2.0, avgCost=373690.89016675)
# 2024-05-23 15:59:18,490 ib_async.wrapper ERROR Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# 2024-05-23 15:59:49,205 ib_async.wrapper ERROR Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# 2024-05-23 15:59:49,712 ib_async.wrapper ERROR Error 317, reqId 6: Market depth data has been RESET. Please empty deep book contents before applying any new entries., contract: Contract(secType='FUT', conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', exchange='CME', currency='USD', localSymbol='NQM4', tradingClass='NQ')
# 2024-05-23 15:59:49,715 ib_async.wrapper INFO Warning 2103, reqId -1: Market data farm connection is broken:usfuture
# 2024-05-23 15:59:49,719 ib_async.wrapper INFO Warning 2103, reqId -1: Market data farm connection is broken:usfarm
# 2024-05-23 15:59:49,721 ib_async.wrapper INFO Warning 2157, reqId -1: Sec-def data farm connection is broken:secdefil

# %%
def parse_ibrecords(data_array):

    data_list = []

    for obj in data_array:
        data = {}

        if hasattr(obj, "contract"):
            util.logging.debug(obj.contract)
            contract = util.dataclassNonDefaults(obj.contract)
            data = {**data, **contract}

        if hasattr(obj, "order"):
            util.logging.debug(obj.order)
            order = util.dataclassNonDefaults(obj.order)
            order.pop("softDollarTier")
            data = {**data, **order}

        if hasattr(obj, "orderStatus"):
            util.logging.debug(obj.orderStatus)
            orderStatus = util.dataclassNonDefaults(obj.orderStatus)
            data = {**data, **orderStatus}

        if hasattr(obj, "fills"):
            util.logging.debug(obj.fills)
            fills = {"fills": obj.fills}
            data = {**data, **fills}

        if hasattr(obj, "log"):
            util.logging.debug(obj.log)
            logs = {"log": [util.dataclassAsDict(e) for e in obj.log]}
            data = {**data, **logs}

        if hasattr(obj, "advancedError"):
            util.logging.debug(obj.advancedError)
            advancedError = {"advancedError": obj.advancedError}
            data = {**data, **advancedError}

        if type(obj) == Order:
            util.logging.debug(obj)
            order = util.dataclassNonDefaults(obj)
            order.pop("softDollarTier")
            data = {**data, **order}

        data_list.append(data)

    return data_list


def print_ibrecords_table(
    data_array,
    cols=[
        "localSymbol",
        "permId",
        "status",
        "orderType",
        "action",
        "lmtPrice",
        "remaining",
    ],
):
    df = pd.DataFrame(data_array)
    df = df[cols]
    print(df)


# openTrades = parse_ibrecords(ib.openTrades())
accountSummary = ib.accountSummary()
accountValues = ib.accountValues()

openTrades = parse_ibrecords(ib.openTrades())
# util.df([d for d in openTrades])

openOrders = parse_ibrecords(ib.openOrders())
# util.df([d for d in openOrders])

trades = parse_ibrecords(ib.trades())
# util.df([d for d in trades])

orders = parse_ibrecords(ib.orders())
# util.df([d for d in orders])

# %%
openTrades
# Out:
# [{'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 311,
#   'clientId': 54,
#   'permId': 1735429010,
#   'action': 'SELL',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18766.75,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 56, 52, 987711, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 378,
#   'clientId': 6,
#   'permId': 1735430610,
#   'action': 'BUY',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18670.25,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 56, 53, 28718, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 379,
#   'clientId': 6,
#   'permId': 1735430611,
#   'action': 'BUY',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18670.25,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 56, 53, 28718, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'permId': 2099801404,
#   'action': 'BUY',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18040.5,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaGroup': '2099801403',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 56, 53, 28718, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 271,
#   'clientId': 69,
#   'permId': 196158554,
#   'action': 'SELL',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18924.5,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 56, 53, 28718, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 196,
#   'clientId': 69,
#   'permId': 196158479,
#   'action': 'SELL',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 19021.75,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 56, 53, 28718, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 397,
#   'clientId': 40,
#   'permId': 1735431102,
#   'action': 'SELL',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18687.25,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'trailStopPrice': 18688.25,
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 56, 53, 28718, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''}]

# %%
print("POSITIONS::")
future = [pos for pos in ib.positions() if pos.contract.secType == "FUT"]
for f in future:
    print(f"{f.contract.symbol} {f.position} @ {f.avgCost/float(contract.multiplier)}")
print()
# Out:
# POSITIONS::
# NQ 3.0 @ 18665.046700696672

# %%
# print multiple columns of a dictionary
{k: openTrades[0][k] for k in ["symbol", "conId", "localSymbol", "secType"]}

# %%
temp
# Out:
# {'secType': 'FUT',
#  'conId': 620730920,
#  'symbol': 'NQ',
#  'lastTradeDateOrContractMonth': '20240621',
#  'right': '?',
#  'multiplier': '20',
#  'exchange': 'CME',
#  'currency': 'USD',
#  'localSymbol': 'NQM4',
#  'tradingClass': 'NQ',
#  'orderId': 311,
#  'clientId': 54,
#  'permId': 1735429010,
#  'action': 'SELL',
#  'totalQuantity': 1.0,
#  'orderType': 'LMT',
#  'lmtPrice': 18766.75,
#  'auxPrice': 0.0,
#  'tif': 'GTC',
#  'ocaType': 3,
#  'displaySize': 2147483647,
#  'trailStopPrice': 18767.75,
#  'volatilityType': 0,
#  'deltaNeutralOrderType': 'None',
#  'referencePriceType': 0,
#  'account': 'U10394496',
#  'clearingIntent': 'IB',
#  'adjustedOrderType': 'None',
#  'cashQty': 0.0,
#  'dontUseAutoPriceForHedge': True,
#  'status': 'Submitted',
#  'remaining': 1.0,
#  'fills': [],
#  'log': [{'time': datetime.datetime(2024, 5, 23, 18, 55, 52, 636184, tzinfo=datetime.timezone.utc),
#    'status': 'Submitted',
#    'message': '',
#    'errorCode': 0}],
#  'advancedError': ''}

# %%
print(
    util.df(ib.openOrders())
    .sort_values("lmtPrice", ascending=False)
    .loc[
        :,
        [
            "orderId",
            "permId",
            "action",
            "totalQuantity",
            "orderType",
            "lmtPrice",
            "tif",
        ],
    ]
)

# %%
util.df(ib.positions()).sort_values("account", ascending=False)

# %%
p

# %%
openOrders[0]

# %%
openOrders = ib.openOrders()
util.logging.debug(
    util.df(openOrders)
    .sort_values("lmtPrice", ascending=False)
    .loc[
        :,
        [
            "orderId",
            "permId",
            "action",
            "totalQuantity",
            "orderType",
            "lmtPrice",
            "tif",
        ],
    ]
)

# %%
util.df([t.orderStatus for t in ib.reqAllOpenOrders()])

# %%
df = util.df(
    [
        t.order
        for t in ib.openTrades()
        if t.orderStatus.status == "Submitted"
        or t.orderStatus.status == "PreSubmitted"
        or t.orderStatus.status == "PendingSubmit"
    ]
)

# %%
df[df["permId"] == 1394515158]

# %%
def print_openorders():
    orders = ib.openOrders()
    orders.sort(key=lambda order: order.lmtPrice)

    # Order(orderId=658, clientId=3124, permId=342738244, action='SELL', totalQuantity=1.0, orderType='LMT', lmtPrice=17692.5, auxPrice=0.0, tif='GTC', ocaType=3, displaySize=2147483647, rule80A='0', openClose='', volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='U10394496', clearingIntent='IB', adjustedOrderType='None', cashQty=0.0, dontUseAutoPriceForHedge=True)

    util.logging.debug(f"orderId\tpermId\t\taction\ttotalQuantity\tlmtPrice\ttif")
    for order in orders:
        util.logging.debug(
            f"{order.orderId}\t{order.permId}\t{order.orderType}\t{order.action}\t{order.totalQuantity}\t{order.lmtPrice} \t{order.tif}"
        )
    util.logging.debug()


print_openorders()

# %%
openOrders = ib.openOrders()
openTrades = ib.openTrades()

# %%
obj = openTrades[0]
if hasattr(obj, "contract"):
    util.logging.debug(obj.contract)

if hasattr(obj, "order"):
    util.logging.debug(obj.order)

if hasattr(obj, "orderStatus"):
    util.logging.debug(obj.orderStatus)

if hasattr(obj, "fills"):
    util.logging.debug(obj.fills)

if hasattr(obj, "log"):
    util.logging.debug(obj.log)

if hasattr(obj, "advancedError"):
    util.logging.debug(obj.advancedError)

# %%
def parse_ibrecords(data_array):

    data_list = []

    for obj in data_array:
        data = {}

        if hasattr(obj, "contract"):
            util.logging.debug(obj.contract)
            contract = util.dataclassNonDefaults(obj.contract)
            data = {**data, **contract}

        if hasattr(obj, "order"):
            util.logging.debug(obj.order)
            order = util.dataclassNonDefaults(obj.order)
            order.pop("softDollarTier")
            data = {**data, **order}

        if hasattr(obj, "orderStatus"):
            util.logging.debug(obj.orderStatus)
            orderStatus = util.dataclassNonDefaults(obj.orderStatus)
            data = {**data, **orderStatus}

        if hasattr(obj, "fills"):
            util.logging.debug(obj.fills)
            fills = {"fills": obj.fills}
            data = {**data, **fills}

        if hasattr(obj, "log"):
            util.logging.debug(obj.log)
            logs = {"log": [util.dataclassAsDict(e) for e in obj.log]}
            data = {**data, **logs}

        if hasattr(obj, "advancedError"):
            util.logging.debug(obj.advancedError)
            advancedError = {"advancedError": obj.advancedError}
            data = {**data, **advancedError}

        util.logging.debug(f"Processed orderId :: {order['permId']}")

        data_list.append(data)

    return data_list


parse_ibrecords([openTrades[0]])

# %%
import sqlite3
from datetime import datetime
from typing import Dict, List, Any, Optional


class SQLiteWrapper:
    def __init__(self, db_name: str, drop_tables=[]):
        self.conn = sqlite3.connect(db_name)
        self.drop_tables(drop_tables)
        self.create_trades_table()

    def drop_tables(self, drop_tables: List[str]):
        for tbl in drop_tables:
            drop_table_sql = f"DROP TABLE IF EXISTS {tbl};"
            self.conn.execute(drop_table_sql)
            self.conn.commit()

    def create_trades_table(self):

        create_table_sql = """
        CREATE TABLE IF NOT EXISTS trades (
            secType TEXT,
            conId INTEGER,
            symbol TEXT,
            lastTradeDateOrContractMonth TEXT,
            right TEXT,
            multiplier TEXT,
            exchange TEXT,
            currency TEXT,
            localSymbol TEXT,
            tradingClass TEXT,
            orderId INTEGER,
            clientId INTEGER,
            permId INTEGER PRIMARY KEY,
            action TEXT,
            totalQuantity REAL,
            filledQuantity REAL,
            orderType TEXT,
            lmtPrice REAL,
            auxPrice REAL,
            trailStopPrice REAL,
            strike REAL,
            tif TEXT,
            parentPermId INTEGER,
            ocaType INTEGER,
            displaySize INTEGER,
            rule80A TEXT,
            openClose TEXT,
            volatilityType INTEGER,
            deltaNeutralOrderType TEXT,
            shareholder TEXT,
            referencePriceType INTEGER,
            refFuturesConId INTEGER,
            account TEXT,
            clearingIntent TEXT,
            autoCancelDate TEXT,
            adjustedOrderType TEXT,
            cashQty REAL,
            dontUseAutoPriceForHedge INTEGER,
            fills TEXT,
            log TEXT,
            advancedError TEXT,
            status TEXT,
            remaining REAL,
            ocaGroup TEXT
        );
        """
        self.conn.execute(create_table_sql)
        self.conn.commit()

    def upsert_trades_record(self, data: Dict[str, Any]):
        # Convert datetime objects in log to string
        log_entries = data.get("log", [])
        for entry in log_entries:
            entry["time"] = entry["time"].isoformat()
        data["log"] = str(log_entries)

        # Convert fills list to string
        data["fills"] = str(data.get("fills", []))

        # Handle boolean conversion
        data["dontUseAutoPriceForHedge"] = int(data["dontUseAutoPriceForHedge"])

        keys = ", ".join(data.keys())
        question_marks = ", ".join("?" for _ in data)
        update_clause = ", ".join(f"{key}=excluded.{key}" for key in data)

        upsert_sql = f"""
        INSERT INTO trades ({keys})
        VALUES ({question_marks})
        ON CONFLICT(permId) DO UPDATE SET
        {update_clause};
        """

        values = tuple(data.values())
        self.conn.execute(upsert_sql, values)
        self.conn.commit()

    def read_record(self, permId: int) -> Optional[Dict[str, Any]]:
        select_sql = "SELECT * FROM orders WHERE permId = ?;"
        cursor = self.conn.execute(select_sql, (permId,))
        row = cursor.fetchone()
        if row:
            col_names = [description[0] for description in cursor.description]
            record = dict(zip(col_names, row))
            # Convert log string back to list of dicts
            record["log"] = eval(record["log"])
            # Convert fills string back to list
            record["fills"] = eval(record["fills"])
            # Convert integer back to boolean
            record["dontUseAutoPriceForHedge"] = bool(
                record["dontUseAutoPriceForHedge"]
            )
            return record
        return None

    def close(self):
        self.conn.close()


def parse_OpenTrades(ib: IB):
    trades = ib.trades()

    data = None
    data_list = []

    for trade in trades:
        contract = util.dataclassNonDefaults(trade.contract)
        order = util.dataclassNonDefaults(trade.order)
        order.pop("softDollarTier")
        orderStatus = util.dataclassNonDefaults(trade.orderStatus)
        order["fills"] = trade.fills
        order["log"] = [util.dataclassAsDict(e) for e in trade.log]
        order["advancedError"] = trade.advancedError

        util.logging.debug(f"Processing trade with orderId: {order['permId']}")

        data = {**contract, **order, **orderStatus}

        data_list.append(data)

    return data_list


def insert_OpenTrades(ib: IB, db: SQLiteWrapper):
    data_list = parse_OpenTrades(ib)

    for data in data_list:
        try:
            db.upsert_trades_record(data)

        except Exception as e:
            util.logging.debug(f"Error upserting record: {e}")
            util.logging.debug(data)

    return True


def test_trades_upsert():
    # db = SQLiteWrapper('test.db', drop_tables = ['trades', 'orders'])
    db = SQLiteWrapper("test.db", drop_tables=["trades"])

    insert_OpenTrades(ib, db)

    db.close()

    return True


def test_read_record():
    db = SQLiteWrapper("test.db")
    record = db.read_record(262255346)
    util.logging.debug(record)
    db.close()
    return True


# Example usage
if __name__ == "__main__":
    test_trades_upsert()
